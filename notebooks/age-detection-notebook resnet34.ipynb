# %%
import os
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.models import  Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
def load_data(dataset_path):
    def extract_age(file_name):
        return int(file_name.split('_')[0])

    def extract_file_path(file_name):
        return os.path.join(dataset_path, file_name)

    file_names = os.listdir(dataset_path)
    ages = pd.Series(file_names).apply(extract_age)
    file_paths = pd.Series(file_names).apply(extract_file_path)

    df = pd.DataFrame({'Images': file_paths, 'Ages': ages})

    return df


dataset_path = './Datasets/imdbwiki-200-fixed/'
df = load_data(dataset_path)

dataset_path = './Datasets/UTKFace/'

#df = load_data(dataset_path)

df = pd.concat([df,load_data(dataset_path)])
df # 100k images
# Out:
#                                                   Images  Ages
# 0      ./Datasets/imdbwiki-200-fixed/45_nm0000171_rm4...    45
# 1      ./Datasets/imdbwiki-200-fixed/45_nm0604448_rm1...    45
# 2      ./Datasets/imdbwiki-200-fixed/41_35847230_1972...    41
# 3      ./Datasets/imdbwiki-200-fixed/15_nm1767820_rm3...    15
# 4      ./Datasets/imdbwiki-200-fixed/19_nm0334159_rm5...    19
# ...                                                  ...   ...
# 23703  ./Datasets/UTKFace/26_0_1_20170116204952113.jp...    26
# 23704  ./Datasets/UTKFace/59_1_2_20170104212726717.jp...    59
# 23705  ./Datasets/UTKFace/56_1_0_20170104185820366.jp...    56
# 23706  ./Datasets/UTKFace/40_0_0_20170117121759794.jp...    40
# 23707  ./Datasets/UTKFace/4_0_0_20170110212621808.jpg...     4
#
# [103558 rows x 2 columns]

# %%
plt.hist(df['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample

# define maximum number of samples to keep

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if i>80 or i<1:
        dfs[i] = None
    elif dfs[i].shape[0] < 2:
        dfs[i] = None

# Concatenate dataframes
df = pd.concat(dfs)  # 23k images

# %%
plt.hist(df['Ages'], bins=80, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample
import cv2
import numpy as np
import pandas as pd


def variance_of_laplacian(image):
    return cv2.Laplacian(image, cv2.CV_64F).var()


def get_image_var(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return variance_of_laplacian(gray)


max_samples = 1000

# Calculate variance of laplacian for each image and add to new column 'image_var'
df['image_var'] = df['Images'].apply(get_image_var)

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if dfs[i].shape[0] > max_samples:
        # Sort by 'image_var' column and reset index
        dfs[i] = dfs[i].sort_values(
            'image_var', ascending=False).reset_index(drop=True)
        # Resample the first 'max_samples' rows after sorting
        dfs[i] = resample(dfs[i].iloc[:max_samples, :],
                          replace=False, n_samples=max_samples, random_state=124)

df_downsampled = pd.concat(dfs)

# %%
import matplotlib.pyplot as plt

average_var_before = df.groupby('Ages')['image_var'].mean()

# Calculate average variance of laplacian for each age group after downsampling
average_var_after = df_downsampled.groupby('Ages')['image_var'].mean()

# Convert series to dataframe for easier plotting
average_var_before = average_var_before.reset_index()
average_var_after = average_var_after.reset_index()

# Plot before downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_before['Ages'], average_var_before['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('Before Downsampling')
plt.show()

# Plot after downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_after['Ages'], average_var_after['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('After Downsampling')
plt.show()

# %%
df_downsampled
# Out:
#                                                   Images  Ages   image_var
# 80     ./Datasets/UTKFace/1_0_3_20161220221723490.jpg...     1  216.213870
# 789    ./Datasets/UTKFace/1_0_2_20161219211707638.jpg...     1   21.367930
# 869    ./Datasets/UTKFace/1_1_2_20161219192458643.jpg...     1   17.849174
# 518    ./Datasets/UTKFace/1_1_0_20170109192729677.jpg...     1   39.878072
# 794    ./Datasets/UTKFace/1_0_2_20161219194820459.jpg...     1   21.247380
# ...                                                  ...   ...         ...
# 22637  ./Datasets/UTKFace/80_0_1_20170116003703261.jp...    80  368.087987
# 22901  ./Datasets/UTKFace/80_0_0_20170117173759783.jp...    80   55.670891
# 22990  ./Datasets/UTKFace/80_0_0_20170117175134292.jp...    80   49.548661
# 23387  ./Datasets/UTKFace/80_1_0_20170110131358567.jp...    80   35.838599
# 23682  ./Datasets/UTKFace/80_1_0_20170110141751087.jp...    80  137.122496
#
# [56772 rows x 3 columns]

# %%
plt.hist(df_downsampled['Ages'], bins=80, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
train_df, test_df = train_test_split(df, stratify=df['Ages'], test_size=0.2, random_state=42)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)



train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    class_mode='raw',
    batch_size=32
)

validation_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    shuffle=False,
    class_mode='raw',
    batch_size=32,
)
# Out:
# Found 81984 validated image filenames.
# Found 20496 validated image filenames.

# %%
#train_generator.next()

# %%
# for img,label in next(train_generator):
#         plt.imshow(img.astype('uint8'))  # convert float image to int for display
#         plt.show()
#         input()

# %%
# import cv2
# import matplotlib.pyplot as plt
# import os
# import random

# # Set the path to the directory containing the images
# path_to_images = "./Datasets/imdbwiki-faces"

# # Get a list of all image filenames in the directory
# image_filenames = os.listdir(path_to_images)

# # Choose a random filename
# while True:
#     random_filename = random.choice(image_filenames)

#     # Construct the full path to the image
#     full_image_path = os.path.join(path_to_images, random_filename)

#     # Read the image using OpenCV
#     image = cv2.imread(full_image_path)

#     # Convert the image from BGR to RGB
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Display the image using matplotlib
#     plt.imshow(image)
#     plt.show()
#     input()

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Conv2D, BatchNormalization, Activation, Add, MaxPool2D, AveragePooling2D, GlobalAveragePooling2D, Dense


def identity_block(X, filters, kernel_regularizer):
    shortcut = X

    X = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1),
               padding='same', kernel_regularizer=kernel_regularizer)(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    X = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1),
               padding='same', kernel_regularizer=kernel_regularizer)(X)
    X = BatchNormalization()(X)

    X = Add()([X, shortcut])
    X = Activation('relu')(X)

    return X


def convolutional_block(X, filters, kernel_regularizer):
    shortcut = Conv2D(filters, kernel_size=(
        1, 1), strides=(2, 2), padding='valid')(X)
    shortcut = BatchNormalization()(shortcut)

    X = Conv2D(filters, kernel_size=(3, 3), strides=(2, 2),
               padding='same', kernel_regularizer=kernel_regularizer)(X)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)

    X = Conv2D(filters, kernel_size=(3, 3), strides=(1, 1),
               padding='same', kernel_regularizer=kernel_regularizer)(X)
    X = BatchNormalization()(X)

    X = Add()([X, shortcut])
    X = Activation('relu')(X)

    return X


def ResNet34(input_shape, l2_lambda=0.0001):
    X_input = Input(input_shape)

    X = Conv2D(64, kernel_size=(7, 7), strides=(2, 2),
               padding='same', kernel_regularizer=l2(l2_lambda))(X_input)
    X = BatchNormalization()(X)
    X = Activation('relu')(X)
    X = MaxPool2D((3, 3), strides=(2, 2), padding='same')(X)

    X = convolutional_block(X, 64, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 64, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 64, kernel_regularizer=l2(l2_lambda))

    X = convolutional_block(X, 128, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 128, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 128, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 128, kernel_regularizer=l2(l2_lambda))

    X = convolutional_block(X, 256, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 256, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 256, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 256, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 256, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 256, kernel_regularizer=l2(l2_lambda))

    X = convolutional_block(X, 512, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 512, kernel_regularizer=l2(l2_lambda))
    X = identity_block(X, 512, kernel_regularizer=l2(l2_lambda))

    X = GlobalAveragePooling2D()(X)

    X = Dense(1, kernel_initializer='he_normal', activation='relu',
              kernel_regularizer=l2(l2_lambda))(X)

    model = Model(inputs=X_input, outputs=X, name='ResNet34')

    return model


model = ResNet34((200, 200, 1))
model.compile(optimizer='adam', loss='mse', metrics=['mae'])
agemodel = model
# Out:
# 2023-06-14 10:22:33.889170: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.043334: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.043536: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.045122: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.045340: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.045521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.663232: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.663412: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.663528: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-14 10:22:34.663612: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5603 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
#agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
agemodel.summary()
# Out:
# Model: "ResNet34"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 200, 200, 1  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 100, 100, 64  3200        ['input_1[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 100, 100, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  activation (Activation)        (None, 100, 100, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 50, 50, 64)   0           ['activation[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 25, 25, 64)   36928       ['max_pooling2d[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_2[0][0]']
#  rmalization)
#
#  activation_1 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_1[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 25, 25, 64)   4160        ['max_pooling2d[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_3[0][0]']
#  rmalization)
#
#  batch_normalization_1 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_1[0][0]']
#  rmalization)
#
#  add (Add)                      (None, 25, 25, 64)   0           ['batch_normalization_3[0][0]',
#                                                                   'batch_normalization_1[0][0]']
#
#  activation_2 (Activation)      (None, 25, 25, 64)   0           ['add[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_4[0][0]']
#  rmalization)
#
#  activation_3 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_3[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  add_1 (Add)                    (None, 25, 25, 64)   0           ['batch_normalization_5[0][0]',
#                                                                   'activation_2[0][0]']
#
#  activation_4 (Activation)      (None, 25, 25, 64)   0           ['add_1[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_4[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_6[0][0]']
#  rmalization)
#
#  activation_5 (Activation)      (None, 25, 25, 64)   0           ['batch_normalization_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 25, 25, 64)   36928       ['activation_5[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 25, 25, 64)  256         ['conv2d_7[0][0]']
#  rmalization)
#
#  add_2 (Add)                    (None, 25, 25, 64)   0           ['batch_normalization_7[0][0]',
#                                                                   'activation_4[0][0]']
#
#  activation_6 (Activation)      (None, 25, 25, 64)   0           ['add_2[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 13, 13, 128)  73856       ['activation_6[0][0]']
#
#  batch_normalization_9 (BatchNo  (None, 13, 13, 128)  512        ['conv2d_9[0][0]']
#  rmalization)
#
#  activation_7 (Activation)      (None, 13, 13, 128)  0           ['batch_normalization_9[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_7[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 13, 13, 128)  8320        ['activation_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 13, 13, 128)  512        ['conv2d_10[0][0]']
#  ormalization)
#
#  batch_normalization_8 (BatchNo  (None, 13, 13, 128)  512        ['conv2d_8[0][0]']
#  rmalization)
#
#  add_3 (Add)                    (None, 13, 13, 128)  0           ['batch_normalization_10[0][0]',
#                                                                   'batch_normalization_8[0][0]']
#
#  activation_8 (Activation)      (None, 13, 13, 128)  0           ['add_3[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_8[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 13, 13, 128)  512        ['conv2d_11[0][0]']
#  ormalization)
#
#  activation_9 (Activation)      (None, 13, 13, 128)  0           ['batch_normalization_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_9[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 13, 13, 128)  512        ['conv2d_12[0][0]']
#  ormalization)
#
#  add_4 (Add)                    (None, 13, 13, 128)  0           ['batch_normalization_12[0][0]',
#                                                                   'activation_8[0][0]']
#
#  activation_10 (Activation)     (None, 13, 13, 128)  0           ['add_4[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_10[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 13, 13, 128)  512        ['conv2d_13[0][0]']
#  ormalization)
#
#  activation_11 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_11[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 13, 13, 128)  512        ['conv2d_14[0][0]']
#  ormalization)
#
#  add_5 (Add)                    (None, 13, 13, 128)  0           ['batch_normalization_14[0][0]',
#                                                                   'activation_10[0][0]']
#
#  activation_12 (Activation)     (None, 13, 13, 128)  0           ['add_5[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_12[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 13, 13, 128)  512        ['conv2d_15[0][0]']
#  ormalization)
#
#  activation_13 (Activation)     (None, 13, 13, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 13, 13, 128)  147584      ['activation_13[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 13, 13, 128)  512        ['conv2d_16[0][0]']
#  ormalization)
#
#  add_6 (Add)                    (None, 13, 13, 128)  0           ['batch_normalization_16[0][0]',
#                                                                   'activation_12[0][0]']
#
#  activation_14 (Activation)     (None, 13, 13, 128)  0           ['add_6[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 7, 7, 256)    295168      ['activation_14[0][0]']
#
#  batch_normalization_18 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_18[0][0]']
#  ormalization)
#
#  activation_15 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_15[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 7, 7, 256)    33024       ['activation_14[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  batch_normalization_17 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_17[0][0]']
#  ormalization)
#
#  add_7 (Add)                    (None, 7, 7, 256)    0           ['batch_normalization_19[0][0]',
#                                                                   'batch_normalization_17[0][0]']
#
#  activation_16 (Activation)     (None, 7, 7, 256)    0           ['add_7[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_16[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_20[0][0]']
#  ormalization)
#
#  activation_17 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_20[0][0]']
#
#  conv2d_21 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_17[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_21[0][0]']
#  ormalization)
#
#  add_8 (Add)                    (None, 7, 7, 256)    0           ['batch_normalization_21[0][0]',
#                                                                   'activation_16[0][0]']
#
#  activation_18 (Activation)     (None, 7, 7, 256)    0           ['add_8[0][0]']
#
#  conv2d_22 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_18[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_22[0][0]']
#  ormalization)
#
#  activation_19 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_19[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_23[0][0]']
#  ormalization)
#
#  add_9 (Add)                    (None, 7, 7, 256)    0           ['batch_normalization_23[0][0]',
#                                                                   'activation_18[0][0]']
#
#  activation_20 (Activation)     (None, 7, 7, 256)    0           ['add_9[0][0]']
#
#  conv2d_24 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_20[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_24[0][0]']
#  ormalization)
#
#  activation_21 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_24[0][0]']
#
#  conv2d_25 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_21[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_25[0][0]']
#  ormalization)
#
#  add_10 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_25[0][0]',
#                                                                   'activation_20[0][0]']
#
#  activation_22 (Activation)     (None, 7, 7, 256)    0           ['add_10[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_22[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_26[0][0]']
#  ormalization)
#
#  activation_23 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_23[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_27[0][0]']
#  ormalization)
#
#  add_11 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_27[0][0]',
#                                                                   'activation_22[0][0]']
#
#  activation_24 (Activation)     (None, 7, 7, 256)    0           ['add_11[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_24[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_28[0][0]']
#  ormalization)
#
#  activation_25 (Activation)     (None, 7, 7, 256)    0           ['batch_normalization_28[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 7, 7, 256)    590080      ['activation_25[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 7, 7, 256)   1024        ['conv2d_29[0][0]']
#  ormalization)
#
#  add_12 (Add)                   (None, 7, 7, 256)    0           ['batch_normalization_29[0][0]',
#                                                                   'activation_24[0][0]']
#
#  activation_26 (Activation)     (None, 7, 7, 256)    0           ['add_12[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 4, 4, 512)    1180160     ['activation_26[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_31[0][0]']
#  ormalization)
#
#  activation_27 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_31[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_27[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 4, 4, 512)    131584      ['activation_26[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_32[0][0]']
#  ormalization)
#
#  batch_normalization_30 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_30[0][0]']
#  ormalization)
#
#  add_13 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_32[0][0]',
#                                                                   'batch_normalization_30[0][0]']
#
#  activation_28 (Activation)     (None, 4, 4, 512)    0           ['add_13[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_28[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_33[0][0]']
#  ormalization)
#
#  activation_29 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_29[0][0]']
#
#  batch_normalization_34 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_34[0][0]']
#  ormalization)
#
#  add_14 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_34[0][0]',
#                                                                   'activation_28[0][0]']
#
#  activation_30 (Activation)     (None, 4, 4, 512)    0           ['add_14[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_30[0][0]']
#
#  batch_normalization_35 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_35[0][0]']
#  ormalization)
#
#  activation_31 (Activation)     (None, 4, 4, 512)    0           ['batch_normalization_35[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 4, 4, 512)    2359808     ['activation_31[0][0]']
#
#  batch_normalization_36 (BatchN  (None, 4, 4, 512)   2048        ['conv2d_36[0][0]']
#  ormalization)
#
#  add_15 (Add)                   (None, 4, 4, 512)    0           ['batch_normalization_36[0][0]',
#                                                                   'activation_30[0][0]']
#
#  activation_32 (Activation)     (None, 4, 4, 512)    0           ['add_15[0][0]']
#
#  global_average_pooling2d (Glob  (None, 512)         0           ['activation_32[0][0]']
#  alAveragePooling2D)
#
#  dense (Dense)                  (None, 1)            513         ['global_average_pooling2d[0][0]'
#                                                                  ]
#
# ==================================================================================================
# Total params: 21,308,865
# Trainable params: 21,291,713
# Non-trainable params: 17,152
# __________________________________________________________________________________________________

# %%
import math
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=math.sqrt(0.1), patience=6, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

early_stopping = EarlyStopping(monitor='val_loss', patience=9, verbose=1, mode='min', restore_best_weights=True)

model_dir = './Models'
os.makedirs(model_dir, exist_ok=True)

# Check if file exists and create new filename if necessary
base_model_name = "best_model"
suffix = 0
while True:
    model_name = f"{base_model_name}_{suffix}.h5" if suffix > 0 else f"{base_model_name}.h5"
    model_path = os.path.join(model_dir, model_name)
    if not os.path.exists(model_path):
        break
    suffix += 1

model_checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks = [early_stopping, lr_scheduler, model_checkpoint]

# %%
#agemodel = keras.models.load_model('Models/regression_mp_5_24.h5')
#agemodel.summary()

# %%
# from keras import backend as K
# K.set_value(agemodel.optimizer.learning_rate, 0.001)

# %%
history = agemodel.fit(
    train_generator,
    epochs=512,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/512
# 2023-06-14 10:23:05.722893: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-14 10:23:12.323713: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-14 10:23:13.630317: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-14 10:23:13.631807: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x3472ca00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-14 10:23:13.631820: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2023-06-14 10:23:13.650781: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-14 10:23:13.825694: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2562/2562 [==============================] - ETA: 0s - loss: 213.8391 - mae: 11.1284
# 2023-06-14 10:26:09.837213: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 588.36353, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 199s 70ms/step - loss: 213.8391 - mae: 11.1284 - val_loss: 588.3635 - val_mae: 20.3491 - lr: 0.0010
# Epoch 2/512
# 2562/2562 [==============================] - ETA: 0s - loss: 133.4194 - mae: 8.8703
# Epoch 2: val_loss improved from 588.36353 to 542.36060, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 179s 70ms/step - loss: 133.4194 - mae: 8.8703 - val_loss: 542.3606 - val_mae: 19.3388 - lr: 0.0010
# Epoch 3/512
# 2562/2562 [==============================] - ETA: 0s - loss: 119.5568 - mae: 8.2975
# Epoch 3: val_loss improved from 542.36060 to 141.08264, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 179s 70ms/step - loss: 119.5568 - mae: 8.2975 - val_loss: 141.0826 - val_mae: 8.8904 - lr: 0.0010
# Epoch 4/512
# 2562/2562 [==============================] - ETA: 0s - loss: 107.8965 - mae: 7.8008
# Epoch 4: val_loss did not improve from 141.08264
# 2562/2562 [==============================] - 177s 69ms/step - loss: 107.8965 - mae: 7.8008 - val_loss: 409.4683 - val_mae: 16.6051 - lr: 0.0010
# Epoch 5/512
# 2562/2562 [==============================] - ETA: 0s - loss: 98.6652 - mae: 7.3857
# Epoch 5: val_loss did not improve from 141.08264
# 2562/2562 [==============================] - 178s 70ms/step - loss: 98.6652 - mae: 7.3857 - val_loss: 184.6825 - val_mae: 10.8120 - lr: 0.0010
# Epoch 6/512
# 2562/2562 [==============================] - ETA: 0s - loss: 92.3020 - mae: 7.1084
# Epoch 6: val_loss improved from 141.08264 to 99.72933, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 181s 71ms/step - loss: 92.3020 - mae: 7.1084 - val_loss: 99.7293 - val_mae: 7.2902 - lr: 0.0010
# Epoch 7/512
# 2562/2562 [==============================] - ETA: 0s - loss: 87.9356 - mae: 6.9008
# Epoch 7: val_loss did not improve from 99.72933
# 2562/2562 [==============================] - 183s 71ms/step - loss: 87.9356 - mae: 6.9008 - val_loss: 169.8591 - val_mae: 9.7072 - lr: 0.0010
# Epoch 8/512
# 2562/2562 [==============================] - ETA: 0s - loss: 83.7153 - mae: 6.7160
# Epoch 8: val_loss did not improve from 99.72933
# 2562/2562 [==============================] - 182s 71ms/step - loss: 83.7153 - mae: 6.7160 - val_loss: 183.6293 - val_mae: 10.3923 - lr: 0.0010
# Epoch 9/512
# 2562/2562 [==============================] - ETA: 0s - loss: 80.1281 - mae: 6.5415
# Epoch 9: val_loss improved from 99.72933 to 99.53968, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 184s 72ms/step - loss: 80.1281 - mae: 6.5415 - val_loss: 99.5397 - val_mae: 7.2194 - lr: 0.0010
# Epoch 10/512
# 2562/2562 [==============================] - ETA: 0s - loss: 77.4222 - mae: 6.4192
# Epoch 10: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 183s 71ms/step - loss: 77.4222 - mae: 6.4192 - val_loss: 132.0395 - val_mae: 8.5107 - lr: 0.0010
# Epoch 11/512
# 2562/2562 [==============================] - ETA: 0s - loss: 75.1743 - mae: 6.2847
# Epoch 11: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 182s 71ms/step - loss: 75.1743 - mae: 6.2847 - val_loss: 117.1035 - val_mae: 7.9697 - lr: 0.0010
# Epoch 12/512
# 2562/2562 [==============================] - ETA: 0s - loss: 72.5443 - mae: 6.1718
# Epoch 12: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 184s 72ms/step - loss: 72.5443 - mae: 6.1718 - val_loss: 103.4857 - val_mae: 7.5449 - lr: 0.0010
# Epoch 13/512
# 2562/2562 [==============================] - ETA: 0s - loss: 70.6991 - mae: 6.0777
# Epoch 13: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 182s 71ms/step - loss: 70.6991 - mae: 6.0777 - val_loss: 126.9444 - val_mae: 8.5437 - lr: 0.0010
# Epoch 14/512
# 2562/2562 [==============================] - ETA: 0s - loss: 68.9863 - mae: 5.9731
# Epoch 14: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 183s 71ms/step - loss: 68.9863 - mae: 5.9731 - val_loss: 152.5577 - val_mae: 9.2449 - lr: 0.0010
# Epoch 15/512
# 2562/2562 [==============================] - ETA: 0s - loss: 66.8163 - mae: 5.8839
# Epoch 15: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 15: val_loss did not improve from 99.53968
# 2562/2562 [==============================] - 180s 70ms/step - loss: 66.8163 - mae: 5.8839 - val_loss: 101.9658 - val_mae: 7.3702 - lr: 0.0010
# Epoch 16/512
# 2562/2562 [==============================] - ETA: 0s - loss: 58.4286 - mae: 5.4398
# Epoch 16: val_loss improved from 99.53968 to 72.72297, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 180s 70ms/step - loss: 58.4286 - mae: 5.4398 - val_loss: 72.7230 - val_mae: 6.0249 - lr: 3.1623e-04
# Epoch 17/512
# 2562/2562 [==============================] - ETA: 0s - loss: 56.3240 - mae: 5.3244
# Epoch 17: val_loss did not improve from 72.72297
# 2562/2562 [==============================] - 179s 70ms/step - loss: 56.3240 - mae: 5.3244 - val_loss: 92.4693 - val_mae: 7.0157 - lr: 3.1623e-04
# Epoch 18/512
# 2562/2562 [==============================] - ETA: 0s - loss: 54.3306 - mae: 5.2275
# Epoch 18: val_loss did not improve from 72.72297
# 2562/2562 [==============================] - 180s 70ms/step - loss: 54.3306 - mae: 5.2275 - val_loss: 85.0651 - val_mae: 6.6068 - lr: 3.1623e-04
# Epoch 19/512
# 2562/2562 [==============================] - ETA: 0s - loss: 52.9361 - mae: 5.1745
# Epoch 19: val_loss did not improve from 72.72297
# 2562/2562 [==============================] - 180s 70ms/step - loss: 52.9361 - mae: 5.1745 - val_loss: 85.1166 - val_mae: 6.6452 - lr: 3.1623e-04
# Epoch 20/512
# 2562/2562 [==============================] - ETA: 0s - loss: 51.7204 - mae: 5.0844
# Epoch 20: val_loss improved from 72.72297 to 71.95252, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 179s 70ms/step - loss: 51.7204 - mae: 5.0844 - val_loss: 71.9525 - val_mae: 6.0054 - lr: 3.1623e-04
# Epoch 21/512
# 2562/2562 [==============================] - ETA: 0s - loss: 50.3317 - mae: 5.0339
# Epoch 21: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 180s 70ms/step - loss: 50.3317 - mae: 5.0339 - val_loss: 101.9058 - val_mae: 7.4770 - lr: 3.1623e-04
# Epoch 22/512
# 2562/2562 [==============================] - ETA: 0s - loss: 49.1876 - mae: 4.9664
# Epoch 22: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 181s 70ms/step - loss: 49.1876 - mae: 4.9664 - val_loss: 73.6337 - val_mae: 6.1346 - lr: 3.1623e-04
# Epoch 23/512
# 2562/2562 [==============================] - ETA: 0s - loss: 48.0906 - mae: 4.9021
# Epoch 23: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 181s 71ms/step - loss: 48.0906 - mae: 4.9021 - val_loss: 74.2445 - val_mae: 6.0951 - lr: 3.1623e-04
# Epoch 24/512
# 2562/2562 [==============================] - ETA: 0s - loss: 46.7365 - mae: 4.8355
# Epoch 24: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 180s 70ms/step - loss: 46.7365 - mae: 4.8355 - val_loss: 77.0861 - val_mae: 6.2317 - lr: 3.1623e-04
# Epoch 25/512
# 2562/2562 [==============================] - ETA: 0s - loss: 45.9464 - mae: 4.7788
# Epoch 25: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 180s 70ms/step - loss: 45.9464 - mae: 4.7788 - val_loss: 84.1434 - val_mae: 6.5697 - lr: 3.1623e-04
# Epoch 26/512
# 2562/2562 [==============================] - ETA: 0s - loss: 45.0372 - mae: 4.7169
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 26: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 179s 70ms/step - loss: 45.0372 - mae: 4.7169 - val_loss: 89.1215 - val_mae: 6.8637 - lr: 3.1623e-04
# Epoch 27/512
# 2562/2562 [==============================] - ETA: 0s - loss: 41.1656 - mae: 4.4919
# Epoch 27: val_loss did not improve from 71.95252
# 2562/2562 [==============================] - 178s 70ms/step - loss: 41.1656 - mae: 4.4919 - val_loss: 75.8963 - val_mae: 6.1217 - lr: 1.0000e-04
# Epoch 28/512
# 2562/2562 [==============================] - ETA: 0s - loss: 40.0374 - mae: 4.4228
# Epoch 28: val_loss improved from 71.95252 to 71.75801, saving model to ./Models/best_model_29.h5
# 2562/2562 [==============================] - 179s 70ms/step - loss: 40.0374 - mae: 4.4228 - val_loss: 71.7580 - val_mae: 5.9462 - lr: 1.0000e-04
# Epoch 29/512
# 2562/2562 [==============================] - ETA: 0s - loss: 39.2989 - mae: 4.3797
# Epoch 29: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 180s 70ms/step - loss: 39.2989 - mae: 4.3797 - val_loss: 76.1667 - val_mae: 6.1861 - lr: 1.0000e-04
# Epoch 30/512
# 2562/2562 [==============================] - ETA: 0s - loss: 38.7035 - mae: 4.3366
# Epoch 30: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 178s 70ms/step - loss: 38.7035 - mae: 4.3366 - val_loss: 74.1520 - val_mae: 6.0869 - lr: 1.0000e-04
# Epoch 31/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.9761 - mae: 4.2929
# Epoch 31: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 180s 70ms/step - loss: 37.9761 - mae: 4.2929 - val_loss: 72.9520 - val_mae: 6.0087 - lr: 1.0000e-04
# Epoch 32/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.5998 - mae: 4.2635
# Epoch 32: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 180s 70ms/step - loss: 37.5998 - mae: 4.2635 - val_loss: 75.5594 - val_mae: 6.1523 - lr: 1.0000e-04
# Epoch 33/512
# 2562/2562 [==============================] - ETA: 0s - loss: 36.8266 - mae: 4.2181
# Epoch 33: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 179s 70ms/step - loss: 36.8266 - mae: 4.2181 - val_loss: 72.7324 - val_mae: 5.9775 - lr: 1.0000e-04
# Epoch 34/512
# 2562/2562 [==============================] - ETA: 0s - loss: 36.3152 - mae: 4.1902
# Epoch 34: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 34: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 179s 70ms/step - loss: 36.3152 - mae: 4.1902 - val_loss: 74.8002 - val_mae: 6.0581 - lr: 1.0000e-04
# Epoch 35/512
# 2562/2562 [==============================] - ETA: 0s - loss: 34.9241 - mae: 4.0850
# Epoch 35: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 180s 70ms/step - loss: 34.9241 - mae: 4.0850 - val_loss: 73.9072 - val_mae: 6.0114 - lr: 3.1623e-05
# Epoch 36/512
# 2562/2562 [==============================] - ETA: 0s - loss: 34.6985 - mae: 4.0688
# Epoch 36: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 181s 71ms/step - loss: 34.6985 - mae: 4.0688 - val_loss: 78.2979 - val_mae: 6.2626 - lr: 3.1623e-05
# Epoch 37/512
# 2562/2562 [==============================] - ETA: 0s - loss: 34.3707 - mae: 4.0536Restoring model weights from the end of the best epoch: 28.
#
# Epoch 37: val_loss did not improve from 71.75801
# 2562/2562 [==============================] - 182s 71ms/step - loss: 34.3707 - mae: 4.0536 - val_loss: 74.3349 - val_mae: 6.0190 - lr: 3.1623e-05
# Epoch 37: early stopping

# %%
# agemodel.load_weights("model_path")
#all_datagen = ImageDataGenerator(rescale=1./255)
#all_generator = all_datagen.flow_from_dataframe(
#     dataframe=df,
#     x_col='Images',
#     y_col='Ages',
#     target_size=(200, 200),
#     color_mode='grayscale',
#     class_mode='raw',
#     shuffle=False,
#     batch_size=32
# )
predicted_ages = agemodel.predict(validation_generator)

#rain_df.reset_index(drop=True, inplace=True)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
#   7/641 [..............................] - ETA: 13s
# 2023-06-14 12:22:41.769586: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 641/641 [==============================] - 13s 21ms/step
# Mean Squared Error: 67.32383802096658
# Mean Absolute Error: 5.946214019419054

# %%
import numpy as np
# Reset the DataFrame's index
df.reset_index(drop=True, inplace=True)

# Ensure predicted_ages is a 1D array
predicted_ages = np.squeeze(predicted_ages)

# Calculate the absolute errors
absolute_errors = np.abs(test_df['Ages'] - predicted_ages)

# %%
import matplotlib.pyplot as plt
import cv2 

# Calculate the absolute errors
#absolute_errors = np.abs(test_df['Ages'] - predicted_ages)

# Find the index of the max error
max_error_idx = np.argmax(absolute_errors)

# Assuming validation_generator yields a tuple (images, labels) and the images are in the same order as in test_df
# Also assuming it hasn't been iterated over already in your current program run. If it has, you may need to reset the generator.
for i, (images, labels) in enumerate(validation_generator):
    if i == max_error_idx:
        # assuming images is a batch with our desired image as the first entry
        max_error_image = images[0]
        break

# Plot the image
plt.imshow(max_error_image, cv2.COLOR_BGR2RGB)
plt.title(
    f"Largest error image with age {df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 19
#      16         break
#      18 # Plot the image
# ---> 19 plt.imshow(max_error_image, cv2.COLOR_BGR2RGB)
#      20 plt.title(
#      21     f"Largest error image with age {df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
#      22 plt.show()
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/pyplot.py:2668, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
#    2662 @_copy_docstring_and_deprecators(Axes.imshow)
#    2663 def imshow(
#    2664         X, cmap=None, norm=None, *, aspect=None, interpolation=None,
#    2665         alpha=None, vmin=None, vmax=None, origin=None, extent=None,
#    2666         interpolation_stage=None, filternorm=True, filterrad=4.0,
#    2667         resample=None, url=None, data=None, **kwargs):
# -> 2668     __ret = gca().imshow(
#    2669         X, cmap=cmap, norm=norm, aspect=aspect,
#    2670         interpolation=interpolation, alpha=alpha, vmin=vmin,
#    2671         vmax=vmax, origin=origin, extent=extent,
#    2672         interpolation_stage=interpolation_stage,
#    2673         filternorm=filternorm, filterrad=filterrad, resample=resample,
#    2674         url=url, **({"data": data} if data is not None else {}),
#    2675         **kwargs)
#    2676     sci(__ret)
#    2677     return __ret
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/axes/_axes.py:5658, in Axes.imshow(self, X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, **kwargs)
#    5656     aspect = mpl.rcParams['image.aspect']
#    5657 self.set_aspect(aspect)
# -> 5658 im = mimage.AxesImage(self, cmap=cmap, norm=norm,
#    5659                       interpolation=interpolation, origin=origin,
#    5660                       extent=extent, filternorm=filternorm,
#    5661                       filterrad=filterrad, resample=resample,
#    5662                       interpolation_stage=interpolation_stage,
#    5663                       **kwargs)
#    5665 im.set_data(X)
#    5666 im.set_alpha(alpha)
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:454, in make_keyword_only.<locals>.wrapper(*args, **kwargs)
#     448 if len(args) > name_idx:
#     449     warn_deprecated(
#     450         since, message="Passing the %(name)s %(obj_type)s "
#     451         "positionally is deprecated since Matplotlib %(since)s; the "
#     452         "parameter will become keyword-only %(removal)s.",
#     453         name=name, obj_type=f"parameter of {func.__name__}()")
# --> 454 return func(*args, **kwargs)
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/image.py:922, in AxesImage.__init__(self, ax, cmap, norm, interpolation, origin, extent, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     905 @_api.make_keyword_only("3.6", name="cmap")
#     906 def __init__(self, ax,
#     907              cmap=None,
#    (...)
#     917              **kwargs
#     918              ):
#     920     self._extent = extent
# --> 922     super().__init__(
#     923         ax,
#     924         cmap=cmap,
#     925         norm=norm,
#     926         interpolation=interpolation,
#     927         origin=origin,
#     928         filternorm=filternorm,
#     929         filterrad=filterrad,
#     930         resample=resample,
#     931         interpolation_stage=interpolation_stage,
#     932         **kwargs
#     933     )
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/image.py:260, in _ImageBase.__init__(self, ax, cmap, norm, interpolation, origin, filternorm, filterrad, resample, interpolation_stage, **kwargs)
#     247 def __init__(self, ax,
#     248              cmap=None,
#     249              norm=None,
#    (...)
#     257              **kwargs
#     258              ):
#     259     martist.Artist.__init__(self)
# --> 260     cm.ScalarMappable.__init__(self, norm, cmap)
#     261     if origin is None:
#     262         origin = mpl.rcParams['image.origin']
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/cm.py:400, in ScalarMappable.__init__(self, norm, cmap)
#     398 self.set_norm(norm)  # The Normalize instance of this ScalarMappable.
#     399 self.cmap = None  # So that the setter knows we're initializing.
# --> 400 self.set_cmap(cmap)  # The Colormap instance of this ScalarMappable.
#     401 #: The last colorbar associated with this ScalarMappable. May be None.
#     402 self.colorbar = None
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/cm.py:585, in ScalarMappable.set_cmap(self, cmap)
#     576 """
#     577 Set the colormap for luminance data.
#     578
#    (...)
#     581 cmap : `.Colormap` or str or None
#     582 """
#     583 in_init = self.cmap is None
# --> 585 self.cmap = _ensure_cmap(cmap)
#     586 if not in_init:
#     587     self.changed()
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/cm.py:723, in _ensure_cmap(cmap)
#     720 cmap_name = cmap if cmap is not None else mpl.rcParams["image.cmap"]
#     721 # use check_in_list to ensure type stability of the exception raised by
#     722 # the internal usage of this (ValueError vs KeyError)
# --> 723 _api.check_in_list(sorted(_colormaps), cmap=cmap_name)
#     724 return mpl.colormaps[cmap_name]
#
# File /opt/anaconda/lib/python3.10/site-packages/matplotlib/_api/__init__.py:131, in check_in_list(_values, _print_supported_values, **kwargs)
#     129 if _print_supported_values:
#     130     msg += f"; supported values are {', '.join(map(repr, values))}"
# --> 131 raise ValueError(msg)
#
# ValueError: 4 is not a valid value for cmap; supported values are 'Accent', 'Accent_r', 'Blues', 'Blues_r', 'BrBG', 'BrBG_r', 'BuGn', 'BuGn_r', 'BuPu', 'BuPu_r', 'CMRmap', 'CMRmap_r', 'Dark2', 'Dark2_r', 'GnBu', 'GnBu_r', 'Greens', 'Greens_r', 'Greys', 'Greys_r', 'OrRd', 'OrRd_r', 'Oranges', 'Oranges_r', 'PRGn', 'PRGn_r', 'Paired', 'Paired_r', 'Pastel1', 'Pastel1_r', 'Pastel2', 'Pastel2_r', 'PiYG', 'PiYG_r', 'PuBu', 'PuBuGn', 'PuBuGn_r', 'PuBu_r', 'PuOr', 'PuOr_r', 'PuRd', 'PuRd_r', 'Purples', 'Purples_r', 'RdBu', 'RdBu_r', 'RdGy', 'RdGy_r', 'RdPu', 'RdPu_r', 'RdYlBu', 'RdYlBu_r', 'RdYlGn', 'RdYlGn_r', 'Reds', 'Reds_r', 'Set1', 'Set1_r', 'Set2', 'Set2_r', 'Set3', 'Set3_r', 'Spectral', 'Spectral_r', 'Wistia', 'Wistia_r', 'YlGn', 'YlGnBu', 'YlGnBu_r', 'YlGn_r', 'YlOrBr', 'YlOrBr_r', 'YlOrRd', 'YlOrRd_r', 'afmhot', 'afmhot_r', 'autumn', 'autumn_r', 'binary', 'binary_r', 'bone', 'bone_r', 'brg', 'brg_r', 'bwr', 'bwr_r', 'cividis', 'cividis_r', 'cool', 'cool_r', 'coolwarm', 'coolwarm_r', 'copper', 'copper_r', 'cubehelix', 'cubehelix_r', 'flag', 'flag_r', 'gist_earth', 'gist_earth_r', 'gist_gray', 'gist_gray_r', 'gist_heat', 'gist_heat_r', 'gist_ncar', 'gist_ncar_r', 'gist_rainbow', 'gist_rainbow_r', 'gist_stern', 'gist_stern_r', 'gist_yarg', 'gist_yarg_r', 'gnuplot', 'gnuplot2', 'gnuplot2_r', 'gnuplot_r', 'gray', 'gray_r', 'hot', 'hot_r', 'hsv', 'hsv_r', 'inferno', 'inferno_r', 'jet', 'jet_r', 'magma', 'magma_r', 'nipy_spectral', 'nipy_spectral_r', 'ocean', 'ocean_r', 'pink', 'pink_r', 'plasma', 'plasma_r', 'prism', 'prism_r', 'rainbow', 'rainbow_r', 'seismic', 'seismic_r', 'spring', 'spring_r', 'summer', 'summer_r', 'tab10', 'tab10_r', 'tab20', 'tab20_r', 'tab20b', 'tab20b_r', 'tab20c', 'tab20c_r', 'terrain', 'terrain_r', 'turbo', 'turbo_r', 'twilight', 'twilight_r', 'twilight_shifted', 'twilight_shifted_r', 'viridis', 'viridis_r', 'winter', 'winter_r'

# %%
plt.imshow(cv2.cvtColor(max_error_image, cv2.COLOR_BGR2RGB))
plt.title(
    f"Largest error image with age {test_df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper right")
fig2 = plt.figure()
plt.plot(history.history['mae'], color='red', label='mae')
plt.plot(history.history['val_mae'], color='blue', label='val_mae')
fig2.suptitle('MAE', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %%
# fig = plt.figure()
# plt.plot(history.history['mae'], color='red', label='mae')
# plt.plot(history.history['val_mae'], color='blue', label='val_mae')
# fig.suptitle('MAE', fontsize=20)
# plt.legend(loc="upper right")
# plt.show()

# %%
new_model = tf.keras.models.load_model(
    'Models/regression_efficientNet_mp_4_99.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 200, 200, 32)      832
#
#  batch_normalization_30 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 200, 200, 32)      25632
#
#  batch_normalization_31 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 100, 100, 32)     0
#  2D)
#
#  conv2d_26 (Conv2D)          (None, 100, 100, 64)      51264
#
#  batch_normalization_32 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  conv2d_27 (Conv2D)          (None, 100, 100, 64)      102464
#
#  batch_normalization_33 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_28 (Conv2D)          (None, 50, 50, 128)       204928
#
#  batch_normalization_34 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_29 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_35 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_30 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_36 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_31 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_37 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 25, 25, 128)      0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_38 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_39 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_40 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_41 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  batch_normalization_42 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 36864)             0
#
#  dense_6 (Dense)             (None, 256)               9437440
#
#  batch_normalization_43 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_44 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 16,976,097
# Trainable params: 16,898,145
# Non-trainable params: 77,952
# _________________________________________________________________

# %%
predicted_ages = model.predict(validation_generator)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
# 2023-06-13 08:57:27.085395: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 320/320 [==============================] - 9s 25ms/step
# Mean Squared Error: 121.6218245905298
# Mean Absolute Error: 8.389958673074053

# %%
agemodel.save(os.path.join('Models', 'resnet34.h5'))
