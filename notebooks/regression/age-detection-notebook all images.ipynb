# %%
import os
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.models import  Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading data

# %%
def load_data(dataset_path):
    def extract_age(file_name):
        return int(file_name.split('_')[0])

    def extract_file_path(file_name):
        return os.path.join(dataset_path, file_name)

    file_names = os.listdir(dataset_path)
    ages = pd.Series(file_names).apply(extract_age)
    file_paths = pd.Series(file_names).apply(extract_file_path)

    df = pd.DataFrame({'Images': file_paths, 'Ages': ages})

    return df


dataset_path = '../../Datasets/IMDB-WIKI-200/'
df = load_data(dataset_path)

dataset_path = '../../Datasets/UTKFace/'
df = pd.concat([df,load_data(dataset_path)])

df # 100k images
# Out:
#                                                   Images  Ages
# 0      ../../Datasets/IMDB-WIKI-200/0_32851434_1960-1...     0
# 1      ../../Datasets/IMDB-WIKI-200/0_34853027_2012-0...     0
# 2      ../../Datasets/IMDB-WIKI-200/0_6802033_1964-01...     0
# 3      ../../Datasets/IMDB-WIKI-200/0_nm0000233_rm176...     0
# 4      ../../Datasets/IMDB-WIKI-200/0_nm0001580_rm347...     0
# ...                                                  ...   ...
# 23703  ../../Datasets/UTKFace/9_1_3_20161220222856346...     9
# 23704  ../../Datasets/UTKFace/9_1_3_20170104222949455...     9
# 23705  ../../Datasets/UTKFace/9_1_4_20170103200637399...     9
# 23706  ../../Datasets/UTKFace/9_1_4_20170103200814791...     9
# 23707  ../../Datasets/UTKFace/9_1_4_20170103213057382...     9
#
# [103558 rows x 2 columns]

# %% [markdown]
# ## Preparing data

# %%
plt.hist(df['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample

# define maximum number of samples to keep

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if i>80 or i<1:
        dfs[i] = None
    elif dfs[i].shape[0] < 2:
        dfs[i] = None

# Concatenate dataframes
df = pd.concat(dfs)  # 23k images

# %%
plt.hist(df['Ages'], bins=80, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %% [markdown]
# ## Splitting data

# %%
train_df, test_df = train_test_split(df, stratify=df['Ages'], test_size=0.2, random_state=42)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)



train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    class_mode='raw',
    batch_size=32
)

validation_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    shuffle=False,
    class_mode='raw',
    batch_size=32,
)
# Out:
# Found 81984 validated image filenames.
# Found 20496 validated image filenames.

# %% [markdown]
# ## Creating CNN

# %%
agemodel = Sequential()

agemodel.add(Conv2D(32, 5, activation='relu', input_shape=(200, 200, 1), padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))



agemodel.add(Flatten())
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))


agemodel.add(Dense(256, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(128, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(1, activation='relu'))


opt = tf.keras.optimizers.Adam(learning_rate=0.001)

agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
agemodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 200, 32)      832
#
#  batch_normalization (BatchN  (None, 200, 200, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_1 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_2 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_3 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 32)     0
#  )
#
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      51264
#
#  batch_normalization_4 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_5 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_6 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_7 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 50, 50, 128)       204928
#
#  batch_normalization_8 (Batc  (None, 50, 50, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 50, 50, 128)       409728
#
#  batch_normalization_9 (Batc  (None, 50, 50, 128)      512
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_10 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_11 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_12 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_13 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_14 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_15 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  batch_normalization_16 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout (Dropout)           (None, 36864)             0
#
#  dense (Dense)               (None, 256)               9437440
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 17,233,057
# Trainable params: 17,154,721
# Non-trainable params: 78,336
# _________________________________________________________________

# %% [markdown]
# ## Training

# %%
import math
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=math.sqrt(0.1), patience=16, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose=1, mode='min', restore_best_weights=True)

model_dir = '../../Models/age-prediction/'
os.makedirs(model_dir, exist_ok=True)

# Check if file exists and create new filename if necessary
base_model_name = "best_model"
suffix = 0
while True:
    model_name = f"{base_model_name}_{suffix}.h5" if suffix > 0 else f"{base_model_name}.h5"
    model_path = os.path.join(model_dir, model_name)
    if not os.path.exists(model_path):
        break
    suffix += 1

model_checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks = [early_stopping, lr_scheduler, model_checkpoint]

# %%
history = agemodel.fit(
    train_generator,
    epochs=512,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/512
# 2023-06-13 12:02:54.670100: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 2023-06-13 12:02:58.605615: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:424] Loaded cuDNN version 8600
# 2023-06-13 12:03:00.102572: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:637] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2023-06-13 12:03:00.111839: I tensorflow/compiler/xla/service/service.cc:169] XLA service 0x350a1800 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2023-06-13 12:03:00.111851: I tensorflow/compiler/xla/service/service.cc:177]   StreamExecutor device (0): NVIDIA GeForce RTX 3070, Compute Capability 8.6
# 2023-06-13 12:03:00.131548: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2023-06-13 12:03:00.331211: I ./tensorflow/compiler/jit/device_compiler.h:180] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2562/2562 [==============================] - ETA: 0s - loss: 365.8348 - mae: 14.5642
# 2023-06-13 12:11:02.118777: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 221.03650, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 528s 200ms/step - loss: 365.8348 - mae: 14.5642 - val_loss: 221.0365 - val_mae: 11.7281 - lr: 0.0010
# Epoch 2/512
# 2562/2562 [==============================] - ETA: 0s - loss: 216.9262 - mae: 11.5443
# Epoch 2: val_loss improved from 221.03650 to 193.33582, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 522s 204ms/step - loss: 216.9262 - mae: 11.5443 - val_loss: 193.3358 - val_mae: 11.0408 - lr: 0.0010
# Epoch 3/512
# 2562/2562 [==============================] - ETA: 0s - loss: 179.0367 - mae: 10.4174
# Epoch 3: val_loss did not improve from 193.33582
# 2562/2562 [==============================] - 514s 201ms/step - loss: 179.0367 - mae: 10.4174 - val_loss: 290.6559 - val_mae: 13.6820 - lr: 0.0010
# Epoch 4/512
# 2562/2562 [==============================] - ETA: 0s - loss: 149.1535 - mae: 9.4393
# Epoch 4: val_loss improved from 193.33582 to 128.20311, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 514s 201ms/step - loss: 149.1535 - mae: 9.4393 - val_loss: 128.2031 - val_mae: 8.5263 - lr: 0.0010
# Epoch 5/512
# 2562/2562 [==============================] - ETA: 0s - loss: 135.3026 - mae: 8.9763
# Epoch 5: val_loss did not improve from 128.20311
# 2562/2562 [==============================] - 517s 202ms/step - loss: 135.3026 - mae: 8.9763 - val_loss: 138.1421 - val_mae: 8.8518 - lr: 0.0010
# Epoch 6/512
# 2562/2562 [==============================] - ETA: 0s - loss: 124.2348 - mae: 8.5649
# Epoch 6: val_loss improved from 128.20311 to 101.19870, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 528s 206ms/step - loss: 124.2348 - mae: 8.5649 - val_loss: 101.1987 - val_mae: 7.7163 - lr: 0.0010
# Epoch 7/512
# 2562/2562 [==============================] - ETA: 0s - loss: 118.1387 - mae: 8.3282
# Epoch 7: val_loss did not improve from 101.19870
# 2562/2562 [==============================] - 527s 206ms/step - loss: 118.1387 - mae: 8.3282 - val_loss: 152.9874 - val_mae: 9.2483 - lr: 0.0010
# Epoch 8/512
# 2562/2562 [==============================] - ETA: 0s - loss: 112.4856 - mae: 8.1028
# Epoch 8: val_loss did not improve from 101.19870
# 2562/2562 [==============================] - 515s 201ms/step - loss: 112.4856 - mae: 8.1028 - val_loss: 103.5255 - val_mae: 7.6274 - lr: 0.0010
# Epoch 9/512
# 2562/2562 [==============================] - ETA: 0s - loss: 107.6128 - mae: 7.9330
# Epoch 9: val_loss did not improve from 101.19870
# 2562/2562 [==============================] - 511s 200ms/step - loss: 107.6128 - mae: 7.9330 - val_loss: 120.3148 - val_mae: 8.1455 - lr: 0.0010
# Epoch 10/512
# 2562/2562 [==============================] - ETA: 0s - loss: 103.0879 - mae: 7.7465
# Epoch 10: val_loss did not improve from 101.19870
# 2562/2562 [==============================] - 512s 200ms/step - loss: 103.0879 - mae: 7.7465 - val_loss: 123.1063 - val_mae: 8.1727 - lr: 0.0010
# Epoch 11/512
# 2562/2562 [==============================] - ETA: 0s - loss: 100.7334 - mae: 7.6553
# Epoch 11: val_loss improved from 101.19870 to 82.69897, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 505s 197ms/step - loss: 100.7334 - mae: 7.6553 - val_loss: 82.6990 - val_mae: 6.7521 - lr: 0.0010
# Epoch 12/512
# 2562/2562 [==============================] - ETA: 0s - loss: 96.3477 - mae: 7.4946
# Epoch 12: val_loss did not improve from 82.69897
# 2562/2562 [==============================] - 481s 188ms/step - loss: 96.3477 - mae: 7.4946 - val_loss: 92.5767 - val_mae: 7.1624 - lr: 0.0010
# Epoch 13/512
# 2562/2562 [==============================] - ETA: 0s - loss: 94.1288 - mae: 7.3852
# Epoch 13: val_loss improved from 82.69897 to 76.80245, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 94.1288 - mae: 7.3852 - val_loss: 76.8025 - val_mae: 6.5569 - lr: 0.0010
# Epoch 14/512
# 2562/2562 [==============================] - ETA: 0s - loss: 92.1550 - mae: 7.2968
# Epoch 14: val_loss improved from 76.80245 to 75.67572, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 92.1550 - mae: 7.2968 - val_loss: 75.6757 - val_mae: 6.5575 - lr: 0.0010
# Epoch 15/512
# 2562/2562 [==============================] - ETA: 0s - loss: 89.7267 - mae: 7.1957
# Epoch 15: val_loss did not improve from 75.67572
# 2562/2562 [==============================] - 481s 188ms/step - loss: 89.7267 - mae: 7.1957 - val_loss: 91.2610 - val_mae: 7.4465 - lr: 0.0010
# Epoch 16/512
# 2562/2562 [==============================] - ETA: 0s - loss: 87.6766 - mae: 7.1030
# Epoch 16: val_loss did not improve from 75.67572
# 2562/2562 [==============================] - 481s 188ms/step - loss: 87.6766 - mae: 7.1030 - val_loss: 84.6393 - val_mae: 6.7845 - lr: 0.0010
# Epoch 17/512
# 2562/2562 [==============================] - ETA: 0s - loss: 85.4932 - mae: 7.0302
# Epoch 17: val_loss improved from 75.67572 to 73.35359, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 484s 189ms/step - loss: 85.4932 - mae: 7.0302 - val_loss: 73.3536 - val_mae: 6.3956 - lr: 0.0010
# Epoch 18/512
# 2562/2562 [==============================] - ETA: 0s - loss: 84.3012 - mae: 6.9660
# Epoch 18: val_loss did not improve from 73.35359
# 2562/2562 [==============================] - 521s 203ms/step - loss: 84.3012 - mae: 6.9660 - val_loss: 73.3709 - val_mae: 6.4515 - lr: 0.0010
# Epoch 19/512
# 2562/2562 [==============================] - ETA: 0s - loss: 82.5810 - mae: 6.8845
# Epoch 19: val_loss did not improve from 73.35359
# 2562/2562 [==============================] - 516s 201ms/step - loss: 82.5810 - mae: 6.8845 - val_loss: 82.0582 - val_mae: 6.6848 - lr: 0.0010
# Epoch 20/512
# 2562/2562 [==============================] - ETA: 0s - loss: 81.4909 - mae: 6.8337
# Epoch 20: val_loss improved from 73.35359 to 69.51917, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 513s 200ms/step - loss: 81.4909 - mae: 6.8337 - val_loss: 69.5192 - val_mae: 6.2629 - lr: 0.0010
# Epoch 21/512
# 2562/2562 [==============================] - ETA: 0s - loss: 79.8530 - mae: 6.7597
# Epoch 21: val_loss did not improve from 69.51917
# 2562/2562 [==============================] - 512s 200ms/step - loss: 79.8530 - mae: 6.7597 - val_loss: 82.7379 - val_mae: 6.7529 - lr: 0.0010
# Epoch 22/512
# 2562/2562 [==============================] - ETA: 0s - loss: 79.1073 - mae: 6.7318
# Epoch 22: val_loss did not improve from 69.51917
# 2562/2562 [==============================] - 486s 190ms/step - loss: 79.1073 - mae: 6.7318 - val_loss: 79.6988 - val_mae: 6.6049 - lr: 0.0010
# Epoch 23/512
# 2562/2562 [==============================] - ETA: 0s - loss: 78.4721 - mae: 6.7094
# Epoch 23: val_loss improved from 69.51917 to 65.59064, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 78.4721 - mae: 6.7094 - val_loss: 65.5906 - val_mae: 6.0059 - lr: 0.0010
# Epoch 24/512
# 2562/2562 [==============================] - ETA: 0s - loss: 76.5356 - mae: 6.6283
# Epoch 24: val_loss improved from 65.59064 to 65.49236, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 76.5356 - mae: 6.6283 - val_loss: 65.4924 - val_mae: 5.9170 - lr: 0.0010
# Epoch 25/512
# 2562/2562 [==============================] - ETA: 0s - loss: 75.4631 - mae: 6.5800
# Epoch 25: val_loss did not improve from 65.49236
# 2562/2562 [==============================] - 481s 188ms/step - loss: 75.4631 - mae: 6.5800 - val_loss: 65.7144 - val_mae: 5.9794 - lr: 0.0010
# Epoch 26/512
# 2562/2562 [==============================] - ETA: 0s - loss: 74.5217 - mae: 6.5297
# Epoch 26: val_loss did not improve from 65.49236
# 2562/2562 [==============================] - 481s 188ms/step - loss: 74.5217 - mae: 6.5297 - val_loss: 76.3042 - val_mae: 6.4349 - lr: 0.0010
# Epoch 27/512
# 2562/2562 [==============================] - ETA: 0s - loss: 73.2260 - mae: 6.4825
# Epoch 27: val_loss improved from 65.49236 to 64.15095, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 73.2260 - mae: 6.4825 - val_loss: 64.1509 - val_mae: 5.8625 - lr: 0.0010
# Epoch 28/512
# 2562/2562 [==============================] - ETA: 0s - loss: 72.9498 - mae: 6.4526
# Epoch 28: val_loss improved from 64.15095 to 63.64777, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 72.9498 - mae: 6.4526 - val_loss: 63.6478 - val_mae: 5.8489 - lr: 0.0010
# Epoch 29/512
# 2562/2562 [==============================] - ETA: 0s - loss: 71.4235 - mae: 6.3954
# Epoch 29: val_loss did not improve from 63.64777
# 2562/2562 [==============================] - 481s 188ms/step - loss: 71.4235 - mae: 6.3954 - val_loss: 68.3351 - val_mae: 6.0684 - lr: 0.0010
# Epoch 30/512
# 2562/2562 [==============================] - ETA: 0s - loss: 70.6490 - mae: 6.3669
# Epoch 30: val_loss improved from 63.64777 to 62.66251, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 70.6490 - mae: 6.3669 - val_loss: 62.6625 - val_mae: 5.8672 - lr: 0.0010
# Epoch 31/512
# 2562/2562 [==============================] - ETA: 0s - loss: 69.2647 - mae: 6.3157
# Epoch 31: val_loss did not improve from 62.66251
# 2562/2562 [==============================] - 481s 188ms/step - loss: 69.2647 - mae: 6.3157 - val_loss: 62.7807 - val_mae: 5.7545 - lr: 0.0010
# Epoch 32/512
# 2562/2562 [==============================] - ETA: 0s - loss: 68.8448 - mae: 6.2751
# Epoch 32: val_loss improved from 62.66251 to 62.43033, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 68.8448 - mae: 6.2751 - val_loss: 62.4303 - val_mae: 5.7882 - lr: 0.0010
# Epoch 33/512
# 2562/2562 [==============================] - ETA: 0s - loss: 67.8241 - mae: 6.2205
# Epoch 33: val_loss did not improve from 62.43033
# 2562/2562 [==============================] - 481s 188ms/step - loss: 67.8241 - mae: 6.2205 - val_loss: 71.3667 - val_mae: 6.1074 - lr: 0.0010
# Epoch 34/512
# 2562/2562 [==============================] - ETA: 0s - loss: 66.8323 - mae: 6.1823
# Epoch 34: val_loss did not improve from 62.43033
# 2562/2562 [==============================] - 481s 188ms/step - loss: 66.8323 - mae: 6.1823 - val_loss: 71.9236 - val_mae: 6.2029 - lr: 0.0010
# Epoch 35/512
# 2562/2562 [==============================] - ETA: 0s - loss: 65.2998 - mae: 6.1030
# Epoch 35: val_loss did not improve from 62.43033
# 2562/2562 [==============================] - 481s 188ms/step - loss: 65.2998 - mae: 6.1030 - val_loss: 95.2021 - val_mae: 7.1816 - lr: 0.0010
# Epoch 36/512
# 2562/2562 [==============================] - ETA: 0s - loss: 64.7483 - mae: 6.0802
# Epoch 36: val_loss did not improve from 62.43033
# 2562/2562 [==============================] - 481s 188ms/step - loss: 64.7483 - mae: 6.0802 - val_loss: 64.0261 - val_mae: 5.8400 - lr: 0.0010
# Epoch 37/512
# 2562/2562 [==============================] - ETA: 0s - loss: 63.6967 - mae: 6.0445
# Epoch 37: val_loss did not improve from 62.43033
# 2562/2562 [==============================] - 480s 188ms/step - loss: 63.6967 - mae: 6.0445 - val_loss: 66.2949 - val_mae: 5.8605 - lr: 0.0010
# Epoch 38/512
# 2562/2562 [==============================] - ETA: 0s - loss: 63.3432 - mae: 6.0093
# Epoch 38: val_loss improved from 62.43033 to 59.90243, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 63.3432 - mae: 6.0093 - val_loss: 59.9024 - val_mae: 5.5956 - lr: 0.0010
# Epoch 39/512
# 2562/2562 [==============================] - ETA: 0s - loss: 61.4548 - mae: 5.9254
# Epoch 39: val_loss did not improve from 59.90243
# 2562/2562 [==============================] - 480s 188ms/step - loss: 61.4548 - mae: 5.9254 - val_loss: 61.6213 - val_mae: 5.6862 - lr: 0.0010
# Epoch 40/512
# 2562/2562 [==============================] - ETA: 0s - loss: 62.1035 - mae: 5.9664
# Epoch 40: val_loss did not improve from 59.90243
# 2562/2562 [==============================] - 481s 188ms/step - loss: 62.1035 - mae: 5.9664 - val_loss: 63.6854 - val_mae: 5.7533 - lr: 0.0010
# Epoch 41/512
# 2562/2562 [==============================] - ETA: 0s - loss: 60.0349 - mae: 5.8645
# Epoch 41: val_loss improved from 59.90243 to 59.24973, saving model to ./Models/best_model_28.h5
# 2562/2562 [==============================] - 481s 188ms/step - loss: 60.0349 - mae: 5.8645 - val_loss: 59.2497 - val_mae: 5.5297 - lr: 0.0010
# Epoch 42/512
# 2562/2562 [==============================] - ETA: 0s - loss: 59.7500 - mae: 5.8711
# Epoch 42: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 59.7500 - mae: 5.8711 - val_loss: 61.6118 - val_mae: 5.6977 - lr: 0.0010
# Epoch 43/512
# 2562/2562 [==============================] - ETA: 0s - loss: 59.1168 - mae: 5.8257
# Epoch 43: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 59.1168 - mae: 5.8257 - val_loss: 63.0745 - val_mae: 5.7301 - lr: 0.0010
# Epoch 44/512
# 2562/2562 [==============================] - ETA: 0s - loss: 58.0604 - mae: 5.7663
# Epoch 44: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 58.0604 - mae: 5.7663 - val_loss: 61.6356 - val_mae: 5.6870 - lr: 0.0010
# Epoch 45/512
# 2562/2562 [==============================] - ETA: 0s - loss: 57.4773 - mae: 5.7476
# Epoch 45: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 57.4773 - mae: 5.7476 - val_loss: 62.4108 - val_mae: 5.7654 - lr: 0.0010
# Epoch 46/512
# 2562/2562 [==============================] - ETA: 0s - loss: 56.5716 - mae: 5.7090
# Epoch 46: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 56.5716 - mae: 5.7090 - val_loss: 62.7182 - val_mae: 5.7033 - lr: 0.0010
# Epoch 47/512
# 2562/2562 [==============================] - ETA: 0s - loss: 57.0002 - mae: 5.7265
# Epoch 47: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 480s 188ms/step - loss: 57.0002 - mae: 5.7265 - val_loss: 61.2673 - val_mae: 5.6054 - lr: 0.0010
# Epoch 48/512
# 2562/2562 [==============================] - ETA: 0s - loss: 55.2824 - mae: 5.6403
# Epoch 48: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 55.2824 - mae: 5.6403 - val_loss: 64.9710 - val_mae: 5.8016 - lr: 0.0010
# Epoch 49/512
# 2562/2562 [==============================] - ETA: 0s - loss: 54.8279 - mae: 5.6170
# Epoch 49: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 54.8279 - mae: 5.6170 - val_loss: 62.4971 - val_mae: 5.7124 - lr: 0.0010
# Epoch 50/512
# 2562/2562 [==============================] - ETA: 0s - loss: 54.5871 - mae: 5.5983
# Epoch 50: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 54.5871 - mae: 5.5983 - val_loss: 69.0571 - val_mae: 6.0088 - lr: 0.0010
# Epoch 51/512
# 2562/2562 [==============================] - ETA: 0s - loss: 54.0018 - mae: 5.5807
# Epoch 51: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 480s 188ms/step - loss: 54.0018 - mae: 5.5807 - val_loss: 65.3940 - val_mae: 5.8358 - lr: 0.0010
# Epoch 52/512
# 2562/2562 [==============================] - ETA: 0s - loss: 52.1883 - mae: 5.4807
# Epoch 52: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 480s 188ms/step - loss: 52.1883 - mae: 5.4807 - val_loss: 84.8608 - val_mae: 6.7913 - lr: 0.0010
# Epoch 53/512
# 2562/2562 [==============================] - ETA: 0s - loss: 51.9520 - mae: 5.4766
# Epoch 53: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 481s 188ms/step - loss: 51.9520 - mae: 5.4766 - val_loss: 61.7368 - val_mae: 5.6429 - lr: 0.0010
# Epoch 54/512
# 2562/2562 [==============================] - ETA: 0s - loss: 52.5403 - mae: 5.5048
# Epoch 54: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 480s 187ms/step - loss: 52.5403 - mae: 5.5048 - val_loss: 61.4753 - val_mae: 5.6165 - lr: 0.0010
# Epoch 55/512
# 2562/2562 [==============================] - ETA: 0s - loss: 51.2070 - mae: 5.4331
# Epoch 55: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 507s 198ms/step - loss: 51.2070 - mae: 5.4331 - val_loss: 60.7813 - val_mae: 5.6354 - lr: 0.0010
# Epoch 56/512
# 2562/2562 [==============================] - ETA: 0s - loss: 50.9073 - mae: 5.4256
# Epoch 56: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 513s 200ms/step - loss: 50.9073 - mae: 5.4256 - val_loss: 62.2719 - val_mae: 5.6984 - lr: 0.0010
# Epoch 57/512
# 2562/2562 [==============================] - ETA: 0s - loss: 50.5767 - mae: 5.3952
# Epoch 57: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 57: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 50.5767 - mae: 5.3952 - val_loss: 61.0742 - val_mae: 5.5870 - lr: 0.0010
# Epoch 58/512
# 2562/2562 [==============================] - ETA: 0s - loss: 45.7214 - mae: 5.1348
# Epoch 58: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 45.7214 - mae: 5.1348 - val_loss: 60.2578 - val_mae: 5.5375 - lr: 3.1623e-04
# Epoch 59/512
# 2562/2562 [==============================] - ETA: 0s - loss: 45.8425 - mae: 5.1450
# Epoch 59: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 488s 190ms/step - loss: 45.8425 - mae: 5.1450 - val_loss: 60.3485 - val_mae: 5.5431 - lr: 3.1623e-04
# Epoch 60/512
# 2562/2562 [==============================] - ETA: 0s - loss: 44.3980 - mae: 5.0726
# Epoch 60: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 508s 198ms/step - loss: 44.3980 - mae: 5.0726 - val_loss: 60.6719 - val_mae: 5.6023 - lr: 3.1623e-04
# Epoch 61/512
# 2562/2562 [==============================] - ETA: 0s - loss: 43.8750 - mae: 5.0310
# Epoch 61: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 513s 200ms/step - loss: 43.8750 - mae: 5.0310 - val_loss: 62.2528 - val_mae: 5.6306 - lr: 3.1623e-04
# Epoch 62/512
# 2562/2562 [==============================] - ETA: 0s - loss: 43.3448 - mae: 5.0113
# Epoch 62: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 43.3448 - mae: 5.0113 - val_loss: 60.7928 - val_mae: 5.5851 - lr: 3.1623e-04
# Epoch 63/512
# 2562/2562 [==============================] - ETA: 0s - loss: 42.8796 - mae: 4.9752
# Epoch 63: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 42.8796 - mae: 4.9752 - val_loss: 60.8280 - val_mae: 5.5755 - lr: 3.1623e-04
# Epoch 64/512
# 2562/2562 [==============================] - ETA: 0s - loss: 43.1131 - mae: 4.9854
# Epoch 64: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 43.1131 - mae: 4.9854 - val_loss: 62.3565 - val_mae: 5.6659 - lr: 3.1623e-04
# Epoch 65/512
# 2562/2562 [==============================] - ETA: 0s - loss: 41.6993 - mae: 4.9135
# Epoch 65: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 515s 201ms/step - loss: 41.6993 - mae: 4.9135 - val_loss: 62.0255 - val_mae: 5.6076 - lr: 3.1623e-04
# Epoch 66/512
# 2562/2562 [==============================] - ETA: 0s - loss: 41.4407 - mae: 4.8972
# Epoch 66: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 515s 201ms/step - loss: 41.4407 - mae: 4.8972 - val_loss: 61.2803 - val_mae: 5.5506 - lr: 3.1623e-04
# Epoch 67/512
# 2562/2562 [==============================] - ETA: 0s - loss: 40.7500 - mae: 4.8682
# Epoch 67: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 40.7500 - mae: 4.8682 - val_loss: 61.4468 - val_mae: 5.5854 - lr: 3.1623e-04
# Epoch 68/512
# 2562/2562 [==============================] - ETA: 0s - loss: 41.1010 - mae: 4.8889
# Epoch 68: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 41.1010 - mae: 4.8889 - val_loss: 62.0046 - val_mae: 5.6164 - lr: 3.1623e-04
# Epoch 69/512
# 2562/2562 [==============================] - ETA: 0s - loss: 40.6652 - mae: 4.8583
# Epoch 69: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 517s 202ms/step - loss: 40.6652 - mae: 4.8583 - val_loss: 62.6366 - val_mae: 5.6656 - lr: 3.1623e-04
# Epoch 70/512
# 2562/2562 [==============================] - ETA: 0s - loss: 40.0675 - mae: 4.8151
# Epoch 70: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 40.0675 - mae: 4.8151 - val_loss: 62.0934 - val_mae: 5.6476 - lr: 3.1623e-04
# Epoch 71/512
# 2562/2562 [==============================] - ETA: 0s - loss: 40.0027 - mae: 4.8054
# Epoch 71: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 40.0027 - mae: 4.8054 - val_loss: 62.4428 - val_mae: 5.6266 - lr: 3.1623e-04
# Epoch 72/512
# 2562/2562 [==============================] - ETA: 0s - loss: 39.9583 - mae: 4.8043
# Epoch 72: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 515s 201ms/step - loss: 39.9583 - mae: 4.8043 - val_loss: 62.1310 - val_mae: 5.6293 - lr: 3.1623e-04
# Epoch 73/512
# 2562/2562 [==============================] - ETA: 0s - loss: 39.2605 - mae: 4.7744
# Epoch 73: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 73: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 528s 206ms/step - loss: 39.2605 - mae: 4.7744 - val_loss: 62.8074 - val_mae: 5.6804 - lr: 3.1623e-04
# Epoch 74/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.3896 - mae: 4.6580
# Epoch 74: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 525s 205ms/step - loss: 37.3896 - mae: 4.6580 - val_loss: 62.8295 - val_mae: 5.6663 - lr: 1.0000e-04
# Epoch 75/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.9096 - mae: 4.6853
# Epoch 75: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 37.9096 - mae: 4.6853 - val_loss: 63.1933 - val_mae: 5.6484 - lr: 1.0000e-04
# Epoch 76/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.1847 - mae: 4.6359
# Epoch 76: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 514s 200ms/step - loss: 37.1847 - mae: 4.6359 - val_loss: 62.5976 - val_mae: 5.6209 - lr: 1.0000e-04
# Epoch 77/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.6102 - mae: 4.6688
# Epoch 77: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 37.6102 - mae: 4.6688 - val_loss: 62.9108 - val_mae: 5.6252 - lr: 1.0000e-04
# Epoch 78/512
# 2562/2562 [==============================] - ETA: 0s - loss: 36.8688 - mae: 4.6208
# Epoch 78: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 511s 200ms/step - loss: 36.8688 - mae: 4.6208 - val_loss: 63.5354 - val_mae: 5.6487 - lr: 1.0000e-04
# Epoch 79/512
# 2562/2562 [==============================] - ETA: 0s - loss: 37.1428 - mae: 4.6404
# Epoch 79: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 512s 200ms/step - loss: 37.1428 - mae: 4.6404 - val_loss: 63.2343 - val_mae: 5.6478 - lr: 1.0000e-04
# Epoch 80/512
# 2562/2562 [==============================] - ETA: 0s - loss: 36.4507 - mae: 4.5968
# Epoch 80: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 511s 200ms/step - loss: 36.4507 - mae: 4.5968 - val_loss: 63.7776 - val_mae: 5.6746 - lr: 1.0000e-04
# Epoch 81/512
# 2562/2562 [==============================] - ETA: 0s - loss: 36.4860 - mae: 4.6022Restoring model weights from the end of the best epoch: 41.
#
# Epoch 81: val_loss did not improve from 59.24973
# 2562/2562 [==============================] - 516s 201ms/step - loss: 36.4860 - mae: 4.6022 - val_loss: 63.3347 - val_mae: 5.6471 - lr: 1.0000e-04
# Epoch 81: early stopping

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper right")
fig2 = plt.figure()
plt.plot(history.history['mae'], color='red', label='mae')
plt.plot(history.history['val_mae'], color='blue', label='val_mae')
fig2.suptitle('MAE', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ## Saving the model

# %%
agemodel.save(os.path.join('..', os.path.join('..', os.path.join('Models', os.path.join('age-prediction' , 'allImages_5_5.h5')))))

# %% [markdown]
# ## Evaluating the model

# %%
agemodel = tf.keras.models.load_model('../../Models/age-prediction/allImages_5_5.h5', compile=False)
opt = tf.keras.optimizers.Adam(learning_rate=0.001)
agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
# Here you can assign any dataframe you want (df must have Images and Ages columns, where Images column contains paths to images of size 200x200)
df = test_df

# %%
all_datagen = ImageDataGenerator(rescale=1./255)
all_generator = all_datagen.flow_from_dataframe(
    dataframe=df,
    x_col='Images',
    y_col='Ages',
    target_size=(200, 200),
    color_mode='grayscale',
    class_mode='raw',
    shuffle=False,
    batch_size=32
)
predicted_ages = agemodel.predict(all_generator)

mse = mean_squared_error(df['Ages'], predicted_ages)
mae = mean_absolute_error(df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
# Found 20496 validated image filenames.
# 641/641 [==============================] - 113s 176ms/step
# Mean Squared Error: 42.04087311841982
# Mean Absolute Error: 4.7259706066373175

# %%
import numpy as np
# Reset the DataFrame's index
df.reset_index(drop=True, inplace=True)

# Ensure predicted_ages is a 1D array
#predicted_ages = np.squeeze(predicted_ages)
predicted_ages = predicted_ages.reshape(predicted_ages.shape[0])

# Calculate the absolute errors
absolute_errors = np.abs(df['Ages'] - predicted_ages)

# %%
import matplotlib.pyplot as plt
import cv2

# Find the index of the max error
max_error_idx = np.argmax(absolute_errors)
max_error_image = cv2.imread(df['Images'].iloc[max_error_idx])

# Plot the image
plt.imshow(cv2.cvtColor(max_error_image, cv2.COLOR_BGR2RGB))
plt.title(
    f"Largest error image with age {df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
plt.show()

# %%
test_df = df.sample(frac=1).reset_index(drop=True)
i = 0
fix, ax = plt.subplots(ncols=4, figsize=(20,20))
for idx in range(4):
    img = cv2.imread(test_df['Images'].iloc[i + idx])
    ax[idx].imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    ax[idx].title.set_text('Dataset age - {0}, Predicted age - {1}'.format(test_df['Ages'].iloc[i + idx], agemodel.predict(cv2.cvtColor(img, cv2.COLOR_BGR2GRAY).reshape(1, 200, 200, 1) / 255)))
# Out:
# 1/1 [==============================] - 1s 561ms/step
# 1/1 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 30ms/step

# %% [markdown]
# ## Building confusion matrix

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
conf_df = df

# %%
def class_labels_reassign(age):

    if 0 <= age < 3:
        return 0
    elif 3 <= age < 10:
        return 1
    elif 10 <= age < 21:
        return 2
    elif 21 <= age < 28:
        return 3
    elif 28 <= age < 46:
        return 4
    elif 46 <= age < 66:
        return 5
    else:
        return 6

# %%
conf_df['Ages'] = df['Ages'].map(class_labels_reassign)
predicted_ages = np.array(predicted_ages)
reassign = np.vectorize(class_labels_reassign)
conf_predicted = reassign(predicted_ages)

# %%
conf_matrix = confusion_matrix(conf_df['Ages'].astype(int), conf_predicted)

# %%
conf_matrix
# Out:
# array([[ 288,   33,    2,    1,    1,    0,    0],
#        [ 101,  137,  108,   15,   11,    1,    0],
#        [   1,   43,  615,  634,  163,    7,    0],
#        [   1,    0,  248, 2077, 1433,   14,    0],
#        [   0,    0,   38, 1246, 7706,  568,    3],
#        [   0,    1,    5,   14, 1328, 2699,   77],
#        [   0,    0,    0,    2,   39,  494,  342]], dtype=int64)

# %%
disp = ConfusionMatrixDisplay(confusion_matrix=conf_matrix)

# %%
disp.plot()
