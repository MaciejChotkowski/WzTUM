# %%
import os
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.models import  Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
def load_data(dataset_path):
    def extract_age(file_name):
        return int(file_name.split('_')[0])

    def extract_file_path(file_name):
        return os.path.join(dataset_path, file_name)

    file_names = os.listdir(dataset_path)
    ages = pd.Series(file_names).apply(extract_age)
    file_paths = pd.Series(file_names).apply(extract_file_path)

    df = pd.DataFrame({'Images': file_paths, 'Ages': ages})

    return df


dataset_path = './Datasets/imdbwiki-200/'
df = load_data(dataset_path)

dataset_path = './Datasets/UTKFace/'

#df = load_data(dataset_path)

df = pd.concat([df,load_data(dataset_path)])
df # 100k images
# Out:
#                                                   Images  Ages
# 0      ./Datasets/imdbwiki-200/45_nm0000171_rm4064133...    45
# 1      ./Datasets/imdbwiki-200/45_nm0604448_rm1603067...    45
# 2      ./Datasets/imdbwiki-200/41_35847230_1972-03-07...    41
# 3      ./Datasets/imdbwiki-200/15_nm1767820_rm3615668...    15
# 4      ./Datasets/imdbwiki-200/19_nm0334159_rm5364587...    19
# ...                                                  ...   ...
# 23703  ./Datasets/UTKFace/26_0_1_20170116204952113.jp...    26
# 23704  ./Datasets/UTKFace/59_1_2_20170104212726717.jp...    59
# 23705  ./Datasets/UTKFace/56_1_0_20170104185820366.jp...    56
# 23706  ./Datasets/UTKFace/40_0_0_20170117121759794.jp...    40
# 23707  ./Datasets/UTKFace/4_0_0_20170110212621808.jpg...     4
#
# [105187 rows x 2 columns]

# %%
plt.hist(df['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample

# define maximum number of samples to keep
max_samples = 500

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if i > 80:
        dfs[i] = None
    elif dfs[i].shape[0] < 2:
        dfs[i] = None

# Concatenate dataframes
df = pd.concat(dfs)  # 23k images

# %%
plt.hist(df['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample
import cv2
import numpy as np
import pandas as pd


def variance_of_laplacian(image):
    return cv2.Laplacian(image, cv2.CV_64F).var()


def get_image_var(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return variance_of_laplacian(gray)


max_samples = 500

# Calculate variance of laplacian for each image and add to new column 'image_var'
df['image_var'] = df['Images'].apply(get_image_var)

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if dfs[i].shape[0] > max_samples:
        # Sort by 'image_var' column and reset index
        dfs[i] = dfs[i].sort_values(
            'image_var', ascending=False).reset_index(drop=True)
        # Resample the first 'max_samples' rows after sorting
        dfs[i] = resample(dfs[i].iloc[:max_samples, :],
                          replace=False, n_samples=max_samples, random_state=124)

df_downsampled = pd.concat(dfs)

# %%
import matplotlib.pyplot as plt

average_var_before = df.groupby('Ages')['image_var'].mean()

# Calculate average variance of laplacian for each age group after downsampling
average_var_after = df_downsampled.groupby('Ages')['image_var'].mean()

# Convert series to dataframe for easier plotting
average_var_before = average_var_before.reset_index()
average_var_after = average_var_after.reset_index()

# Plot before downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_before['Ages'], average_var_before['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('Before Downsampling')
plt.show()

# Plot after downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_after['Ages'], average_var_after['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('After Downsampling')
plt.show()

# %%
df_downsampled
# Out:
#                                                   Images  Ages   image_var
# 3970   ./Datasets/imdbwiki-200/0_nm0001580_rm34770688...     0  377.585364
# 4852   ./Datasets/imdbwiki-200/0_nm2762027_rm28686965...     0  283.425043
# 10466  ./Datasets/imdbwiki-200/0_nm0000233_rm17660697...     0  347.070117
# 13022  ./Datasets/imdbwiki-200/0_6802033_1964-01-13_1...     0  149.197105
# 18359  ./Datasets/imdbwiki-200/0_32851434_1960-12-16_...     0  654.891187
# ...                                                  ...   ...         ...
# 22637  ./Datasets/UTKFace/80_0_1_20170116003703261.jp...    80  368.087987
# 22901  ./Datasets/UTKFace/80_0_0_20170117173759783.jp...    80   55.670891
# 22990  ./Datasets/UTKFace/80_0_0_20170117175134292.jp...    80   49.548661
# 23387  ./Datasets/UTKFace/80_1_0_20170110131358567.jp...    80   35.838599
# 23682  ./Datasets/UTKFace/80_1_0_20170110141751087.jp...    80  137.122496
#
# [34750 rows x 3 columns]

# %%
plt.hist(df_downsampled['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
train_df, test_df = train_test_split(df_downsampled, stratify=df_downsampled['Ages'], test_size=0.2, random_state=42)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    class_mode='raw',
    batch_size=32
)

validation_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    shuffle=False,
    class_mode='raw',
    batch_size=32,
)
# Out:
# Found 27800 validated image filenames.
# Found 6950 validated image filenames.

# %%
#train_generator.next()

# %%
# for img,label in next(train_generator):
#         plt.imshow(img.astype('uint8'))  # convert float image to int for display
#         plt.show()
#         input()

# %%
# import cv2
# import matplotlib.pyplot as plt
# import os
# import random

# # Set the path to the directory containing the images
# path_to_images = "./Datasets/imdbwiki-faces"

# # Get a list of all image filenames in the directory
# image_filenames = os.listdir(path_to_images)

# # Choose a random filename
# while True:
#     random_filename = random.choice(image_filenames)

#     # Construct the full path to the image
#     full_image_path = os.path.join(path_to_images, random_filename)

#     # Read the image using OpenCV
#     image = cv2.imread(full_image_path)

#     # Convert the image from BGR to RGB
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Display the image using matplotlib
#     plt.imshow(image)
#     plt.show()
#     input()

# %%
agemodel = Sequential()

agemodel.add(Conv2D(32, 5, activation='relu', input_shape=(200, 200, 1), padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))



agemodel.add(Flatten())
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))


agemodel.add(Dense(256, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(128, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(1, activation='relu'))


opt = tf.keras.optimizers.Adam(learning_rate=0.001)

agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
agemodel.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_36 (Conv2D)          (None, 200, 200, 32)      832
#
#  batch_normalization_45 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  conv2d_37 (Conv2D)          (None, 200, 200, 32)      25632
#
#  batch_normalization_46 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  max_pooling2d_12 (MaxPoolin  (None, 100, 100, 32)     0
#  g2D)
#
#  conv2d_38 (Conv2D)          (None, 100, 100, 64)      51264
#
#  batch_normalization_47 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  conv2d_39 (Conv2D)          (None, 100, 100, 64)      102464
#
#  batch_normalization_48 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  max_pooling2d_13 (MaxPoolin  (None, 50, 50, 64)       0
#  g2D)
#
#  conv2d_40 (Conv2D)          (None, 50, 50, 128)       204928
#
#  batch_normalization_49 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_41 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_50 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_42 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_51 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_43 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_52 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_14 (MaxPoolin  (None, 25, 25, 128)      0
#  g2D)
#
#  conv2d_44 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_53 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_45 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_54 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_46 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_55 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_47 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_56 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_15 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 36864)             0
#
#  batch_normalization_57 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 36864)             0
#
#  dense_9 (Dense)             (None, 256)               9437440
#
#  batch_normalization_58 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_10 (Dropout)        (None, 256)               0
#
#  dense_10 (Dense)            (None, 128)               32896
#
#  batch_normalization_59 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_11 (Dropout)        (None, 128)               0
#
#  dense_11 (Dense)            (None, 1)                 129
#
# =================================================================
# Total params: 16,976,097
# Trainable params: 16,898,145
# Non-trainable params: 77,952
# _________________________________________________________________

# %%
import math
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=math.sqrt(0.1), patience=8, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

early_stopping = EarlyStopping(monitor='val_loss', patience=18, verbose=1, mode='min', restore_best_weights=True)

model_dir = './Models'
os.makedirs(model_dir, exist_ok=True)

# Check if file exists and create new filename if necessary
base_model_name = "best_model"
suffix = 0
while True:
    model_name = f"{base_model_name}_{suffix}.h5" if suffix > 0 else f"{base_model_name}.h5"
    model_path = os.path.join(model_dir, model_name)
    if not os.path.exists(model_path):
        break
    suffix += 1

model_checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks = [early_stopping, lr_scheduler, model_checkpoint]

# %%
#agemodel = keras.models.load_model('Models/regression_mp_5_24.h5')
#agemodel.summary()

# %%
history = agemodel.fit(
    train_generator,
    epochs=512,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/512
# 2023-06-11 20:13:34.677849: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 869/869 [==============================] - ETA: 0s - loss: 768.6481 - mae: 22.1498
# 2023-06-11 20:15:18.562282: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 821.18921, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 113s 123ms/step - loss: 768.6481 - mae: 22.1498 - val_loss: 821.1892 - val_mae: 22.9463 - lr: 0.0010
# Epoch 2/512
# 869/869 [==============================] - ETA: 0s - loss: 401.9148 - mae: 16.0519
# Epoch 2: val_loss improved from 821.18921 to 507.26691, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 401.9148 - mae: 16.0519 - val_loss: 507.2669 - val_mae: 18.0753 - lr: 0.0010
# Epoch 3/512
# 869/869 [==============================] - ETA: 0s - loss: 356.3343 - mae: 14.8831
# Epoch 3: val_loss improved from 507.26691 to 433.83643, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 356.3343 - mae: 14.8831 - val_loss: 433.8364 - val_mae: 16.8202 - lr: 0.0010
# Epoch 4/512
# 869/869 [==============================] - ETA: 0s - loss: 324.3294 - mae: 14.2497
# Epoch 4: val_loss improved from 433.83643 to 425.51361, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 324.3294 - mae: 14.2497 - val_loss: 425.5136 - val_mae: 17.4323 - lr: 0.0010
# Epoch 5/512
# 869/869 [==============================] - ETA: 0s - loss: 268.2392 - mae: 12.7750
# Epoch 5: val_loss did not improve from 425.51361
# 869/869 [==============================] - 107s 123ms/step - loss: 268.2392 - mae: 12.7750 - val_loss: 457.5501 - val_mae: 17.2358 - lr: 0.0010
# Epoch 6/512
# 869/869 [==============================] - ETA: 0s - loss: 248.3628 - mae: 12.2886
# Epoch 6: val_loss improved from 425.51361 to 214.89159, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 248.3628 - mae: 12.2886 - val_loss: 214.8916 - val_mae: 11.5616 - lr: 0.0010
# Epoch 7/512
# 869/869 [==============================] - ETA: 0s - loss: 228.3554 - mae: 11.6798
# Epoch 7: val_loss did not improve from 214.89159
# 869/869 [==============================] - 106s 122ms/step - loss: 228.3554 - mae: 11.6798 - val_loss: 441.1616 - val_mae: 16.6310 - lr: 0.0010
# Epoch 8/512
# 869/869 [==============================] - ETA: 0s - loss: 220.4657 - mae: 11.4531
# Epoch 8: val_loss did not improve from 214.89159
# 869/869 [==============================] - 105s 121ms/step - loss: 220.4657 - mae: 11.4531 - val_loss: 891.0619 - val_mae: 23.9367 - lr: 0.0010
# Epoch 9/512
# 869/869 [==============================] - ETA: 0s - loss: 207.8458 - mae: 11.0761
# Epoch 9: val_loss improved from 214.89159 to 191.08249, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 207.8458 - mae: 11.0761 - val_loss: 191.0825 - val_mae: 10.4554 - lr: 0.0010
# Epoch 10/512
# 869/869 [==============================] - ETA: 0s - loss: 199.5015 - mae: 10.8083
# Epoch 10: val_loss improved from 191.08249 to 177.46310, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 199.5015 - mae: 10.8083 - val_loss: 177.4631 - val_mae: 9.7987 - lr: 0.0010
# Epoch 11/512
# 869/869 [==============================] - ETA: 0s - loss: 190.1496 - mae: 10.5499
# Epoch 11: val_loss did not improve from 177.46310
# 869/869 [==============================] - 105s 121ms/step - loss: 190.1496 - mae: 10.5499 - val_loss: 189.1128 - val_mae: 10.5118 - lr: 0.0010
# Epoch 12/512
# 869/869 [==============================] - ETA: 0s - loss: 184.8956 - mae: 10.3710
# Epoch 12: val_loss improved from 177.46310 to 174.58582, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 184.8956 - mae: 10.3710 - val_loss: 174.5858 - val_mae: 9.9216 - lr: 0.0010
# Epoch 13/512
# 869/869 [==============================] - ETA: 0s - loss: 174.4430 - mae: 10.0494
# Epoch 13: val_loss did not improve from 174.58582
# 869/869 [==============================] - 106s 121ms/step - loss: 174.4430 - mae: 10.0494 - val_loss: 244.5691 - val_mae: 12.1656 - lr: 0.0010
# Epoch 14/512
# 869/869 [==============================] - ETA: 0s - loss: 170.2380 - mae: 9.9154
# Epoch 14: val_loss improved from 174.58582 to 154.48671, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 170.2380 - mae: 9.9154 - val_loss: 154.4867 - val_mae: 9.3726 - lr: 0.0010
# Epoch 15/512
# 869/869 [==============================] - ETA: 0s - loss: 162.8970 - mae: 9.6624
# Epoch 15: val_loss did not improve from 154.48671
# 869/869 [==============================] - 107s 123ms/step - loss: 162.8970 - mae: 9.6624 - val_loss: 179.6929 - val_mae: 9.9031 - lr: 0.0010
# Epoch 16/512
# 869/869 [==============================] - ETA: 0s - loss: 160.3626 - mae: 9.5956
# Epoch 16: val_loss did not improve from 154.48671
# 869/869 [==============================] - 107s 123ms/step - loss: 160.3626 - mae: 9.5956 - val_loss: 171.9946 - val_mae: 9.4509 - lr: 0.0010
# Epoch 17/512
# 869/869 [==============================] - ETA: 0s - loss: 154.3221 - mae: 9.3645
# Epoch 17: val_loss did not improve from 154.48671
# 869/869 [==============================] - 105s 121ms/step - loss: 154.3221 - mae: 9.3645 - val_loss: 324.4049 - val_mae: 13.9235 - lr: 0.0010
# Epoch 18/512
# 869/869 [==============================] - ETA: 0s - loss: 151.2290 - mae: 9.2718
# Epoch 18: val_loss improved from 154.48671 to 133.01591, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 151.2290 - mae: 9.2718 - val_loss: 133.0159 - val_mae: 8.4247 - lr: 0.0010
# Epoch 19/512
# 869/869 [==============================] - ETA: 0s - loss: 148.6314 - mae: 9.1862
# Epoch 19: val_loss improved from 133.01591 to 123.80401, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 148.6314 - mae: 9.1862 - val_loss: 123.8040 - val_mae: 8.1915 - lr: 0.0010
# Epoch 20/512
# 869/869 [==============================] - ETA: 0s - loss: 141.3507 - mae: 8.9358
# Epoch 20: val_loss did not improve from 123.80401
# 869/869 [==============================] - 105s 121ms/step - loss: 141.3507 - mae: 8.9358 - val_loss: 182.6235 - val_mae: 10.2239 - lr: 0.0010
# Epoch 21/512
# 869/869 [==============================] - ETA: 0s - loss: 138.0222 - mae: 8.8195
# Epoch 21: val_loss did not improve from 123.80401
# 869/869 [==============================] - 105s 121ms/step - loss: 138.0222 - mae: 8.8195 - val_loss: 155.8581 - val_mae: 8.9452 - lr: 0.0010
# Epoch 22/512
# 869/869 [==============================] - ETA: 0s - loss: 133.7471 - mae: 8.6999
# Epoch 22: val_loss did not improve from 123.80401
# 869/869 [==============================] - 105s 121ms/step - loss: 133.7471 - mae: 8.6999 - val_loss: 125.0450 - val_mae: 8.2112 - lr: 0.0010
# Epoch 23/512
# 869/869 [==============================] - ETA: 0s - loss: 132.5247 - mae: 8.6469
# Epoch 23: val_loss did not improve from 123.80401
# 869/869 [==============================] - 106s 122ms/step - loss: 132.5247 - mae: 8.6469 - val_loss: 145.3697 - val_mae: 8.8893 - lr: 0.0010
# Epoch 24/512
# 869/869 [==============================] - ETA: 0s - loss: 132.8875 - mae: 8.6643
# Epoch 24: val_loss improved from 123.80401 to 109.95676, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 107s 123ms/step - loss: 132.8875 - mae: 8.6643 - val_loss: 109.9568 - val_mae: 7.5296 - lr: 0.0010
# Epoch 25/512
# 869/869 [==============================] - ETA: 0s - loss: 128.9452 - mae: 8.5249
# Epoch 25: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 128.9452 - mae: 8.5249 - val_loss: 138.7559 - val_mae: 8.9872 - lr: 0.0010
# Epoch 26/512
# 869/869 [==============================] - ETA: 0s - loss: 125.2375 - mae: 8.3903
# Epoch 26: val_loss did not improve from 109.95676
# 869/869 [==============================] - 106s 122ms/step - loss: 125.2375 - mae: 8.3903 - val_loss: 112.5605 - val_mae: 7.6628 - lr: 0.0010
# Epoch 27/512
# 869/869 [==============================] - ETA: 0s - loss: 121.6723 - mae: 8.2922
# Epoch 27: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 121.6723 - mae: 8.2922 - val_loss: 122.9453 - val_mae: 8.3036 - lr: 0.0010
# Epoch 28/512
# 869/869 [==============================] - ETA: 0s - loss: 120.1960 - mae: 8.2130
# Epoch 28: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 120.1960 - mae: 8.2130 - val_loss: 110.1816 - val_mae: 7.7254 - lr: 0.0010
# Epoch 29/512
# 869/869 [==============================] - ETA: 0s - loss: 116.6807 - mae: 8.0398
# Epoch 29: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 116.6807 - mae: 8.0398 - val_loss: 112.0922 - val_mae: 7.6669 - lr: 0.0010
# Epoch 30/512
# 869/869 [==============================] - ETA: 0s - loss: 114.9637 - mae: 7.9999
# Epoch 30: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 114.9637 - mae: 7.9999 - val_loss: 115.6472 - val_mae: 7.7907 - lr: 0.0010
# Epoch 31/512
# 869/869 [==============================] - ETA: 0s - loss: 113.5531 - mae: 7.9928
# Epoch 31: val_loss did not improve from 109.95676
# 869/869 [==============================] - 107s 123ms/step - loss: 113.5531 - mae: 7.9928 - val_loss: 215.1754 - val_mae: 7.6156 - lr: 0.0010
# Epoch 32/512
# 869/869 [==============================] - ETA: 0s - loss: 110.2317 - mae: 7.8790
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.00031622778103685084.
#
# Epoch 32: val_loss did not improve from 109.95676
# 869/869 [==============================] - 106s 122ms/step - loss: 110.2317 - mae: 7.8790 - val_loss: 5941.1152 - val_mae: 8.7828 - lr: 0.0010
# Epoch 33/512
# 869/869 [==============================] - ETA: 0s - loss: 101.3736 - mae: 7.5638
# Epoch 33: val_loss improved from 109.95676 to 97.86021, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 101.3736 - mae: 7.5638 - val_loss: 97.8602 - val_mae: 6.8799 - lr: 3.1623e-04
# Epoch 34/512
# 869/869 [==============================] - ETA: 0s - loss: 98.2863 - mae: 7.4738
# Epoch 34: val_loss did not improve from 97.86021
# 869/869 [==============================] - 106s 121ms/step - loss: 98.2863 - mae: 7.4738 - val_loss: 98.8012 - val_mae: 7.0045 - lr: 3.1623e-04
# Epoch 35/512
# 869/869 [==============================] - ETA: 0s - loss: 98.2731 - mae: 7.4500
# Epoch 35: val_loss did not improve from 97.86021
# 869/869 [==============================] - 106s 121ms/step - loss: 98.2731 - mae: 7.4500 - val_loss: 98.8774 - val_mae: 6.9774 - lr: 3.1623e-04
# Epoch 36/512
# 869/869 [==============================] - ETA: 0s - loss: 96.1766 - mae: 7.3922
# Epoch 36: val_loss improved from 97.86021 to 96.61879, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 96.1766 - mae: 7.3922 - val_loss: 96.6188 - val_mae: 6.8367 - lr: 3.1623e-04
# Epoch 37/512
# 869/869 [==============================] - ETA: 0s - loss: 94.2258 - mae: 7.3130
# Epoch 37: val_loss did not improve from 96.61879
# 869/869 [==============================] - 106s 121ms/step - loss: 94.2258 - mae: 7.3130 - val_loss: 98.4008 - val_mae: 6.8811 - lr: 3.1623e-04
# Epoch 38/512
# 869/869 [==============================] - ETA: 0s - loss: 92.8434 - mae: 7.2366
# Epoch 38: val_loss did not improve from 96.61879
# 869/869 [==============================] - 106s 121ms/step - loss: 92.8434 - mae: 7.2366 - val_loss: 100.4495 - val_mae: 7.1058 - lr: 3.1623e-04
# Epoch 39/512
# 869/869 [==============================] - ETA: 0s - loss: 91.8361 - mae: 7.2183
# Epoch 39: val_loss improved from 96.61879 to 95.24313, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 91.8361 - mae: 7.2183 - val_loss: 95.2431 - val_mae: 6.7267 - lr: 3.1623e-04
# Epoch 40/512
# 869/869 [==============================] - ETA: 0s - loss: 90.4861 - mae: 7.1927
# Epoch 40: val_loss did not improve from 95.24313
# 869/869 [==============================] - 106s 121ms/step - loss: 90.4861 - mae: 7.1927 - val_loss: 98.7436 - val_mae: 6.9645 - lr: 3.1623e-04
# Epoch 41/512
# 869/869 [==============================] - ETA: 0s - loss: 89.3317 - mae: 7.1491
# Epoch 41: val_loss did not improve from 95.24313
# 869/869 [==============================] - 106s 121ms/step - loss: 89.3317 - mae: 7.1491 - val_loss: 95.8373 - val_mae: 6.8166 - lr: 3.1623e-04
# Epoch 42/512
# 869/869 [==============================] - ETA: 0s - loss: 87.8576 - mae: 7.1076
# Epoch 42: val_loss did not improve from 95.24313
# 869/869 [==============================] - 106s 121ms/step - loss: 87.8576 - mae: 7.1076 - val_loss: 95.7015 - val_mae: 6.7584 - lr: 3.1623e-04
# Epoch 43/512
# 869/869 [==============================] - ETA: 0s - loss: 87.4525 - mae: 7.0906
# Epoch 43: val_loss improved from 95.24313 to 93.21759, saving model to ./Models/best_model_21.h5
# 869/869 [==============================] - 106s 122ms/step - loss: 87.4525 - mae: 7.0906 - val_loss: 93.2176 - val_mae: 6.6210 - lr: 3.1623e-04
# Epoch 44/512
# 869/869 [==============================] - ETA: 0s - loss: 86.3900 - mae: 7.0240
# Epoch 44: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 86.3900 - mae: 7.0240 - val_loss: 96.9616 - val_mae: 6.7905 - lr: 3.1623e-04
# Epoch 45/512
# 869/869 [==============================] - ETA: 0s - loss: 86.0169 - mae: 7.0350
# Epoch 45: val_loss did not improve from 93.21759
# 869/869 [==============================] - 105s 121ms/step - loss: 86.0169 - mae: 7.0350 - val_loss: 95.0790 - val_mae: 6.7573 - lr: 3.1623e-04
# Epoch 46/512
# 869/869 [==============================] - ETA: 0s - loss: 83.7367 - mae: 6.9248
# Epoch 46: val_loss did not improve from 93.21759
# 869/869 [==============================] - 101s 117ms/step - loss: 83.7367 - mae: 6.9248 - val_loss: 98.6349 - val_mae: 6.7891 - lr: 3.1623e-04
# Epoch 47/512
# 869/869 [==============================] - ETA: 0s - loss: 84.0260 - mae: 6.9575
# Epoch 47: val_loss did not improve from 93.21759
# 869/869 [==============================] - 100s 115ms/step - loss: 84.0260 - mae: 6.9575 - val_loss: 98.7793 - val_mae: 6.7305 - lr: 3.1623e-04
# Epoch 48/512
# 869/869 [==============================] - ETA: 0s - loss: 83.2842 - mae: 6.9339
# Epoch 48: val_loss did not improve from 93.21759
# 869/869 [==============================] - 107s 123ms/step - loss: 83.2842 - mae: 6.9339 - val_loss: 102.0111 - val_mae: 6.9768 - lr: 3.1623e-04
# Epoch 49/512
# 869/869 [==============================] - ETA: 0s - loss: 83.3176 - mae: 6.9236
# Epoch 49: val_loss did not improve from 93.21759
# 869/869 [==============================] - 107s 123ms/step - loss: 83.3176 - mae: 6.9236 - val_loss: 98.1559 - val_mae: 6.9537 - lr: 3.1623e-04
# Epoch 50/512
# 869/869 [==============================] - ETA: 0s - loss: 81.3081 - mae: 6.8712
# Epoch 50: val_loss did not improve from 93.21759
# 869/869 [==============================] - 107s 123ms/step - loss: 81.3081 - mae: 6.8712 - val_loss: 95.6381 - val_mae: 6.7355 - lr: 3.1623e-04
# Epoch 51/512
# 869/869 [==============================] - ETA: 0s - loss: 80.8731 - mae: 6.8441
# Epoch 51: ReduceLROnPlateau reducing learning rate to 0.00010000000639606199.
#
# Epoch 51: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 80.8731 - mae: 6.8441 - val_loss: 93.6935 - val_mae: 6.5996 - lr: 3.1623e-04
# Epoch 52/512
# 869/869 [==============================] - ETA: 0s - loss: 78.3773 - mae: 6.7535
# Epoch 52: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 78.3773 - mae: 6.7535 - val_loss: 93.6875 - val_mae: 6.6171 - lr: 1.0000e-04
# Epoch 53/512
# 869/869 [==============================] - ETA: 0s - loss: 77.3638 - mae: 6.7303
# Epoch 53: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 77.3638 - mae: 6.7303 - val_loss: 95.1113 - val_mae: 6.6705 - lr: 1.0000e-04
# Epoch 54/512
# 869/869 [==============================] - ETA: 0s - loss: 76.3052 - mae: 6.6846
# Epoch 54: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 76.3052 - mae: 6.6846 - val_loss: 94.4220 - val_mae: 6.6680 - lr: 1.0000e-04
# Epoch 55/512
# 869/869 [==============================] - ETA: 0s - loss: 76.1700 - mae: 6.6631
# Epoch 55: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 76.1700 - mae: 6.6631 - val_loss: 95.9416 - val_mae: 6.7342 - lr: 1.0000e-04
# Epoch 56/512
# 869/869 [==============================] - ETA: 0s - loss: 76.0509 - mae: 6.6481
# Epoch 56: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 76.0509 - mae: 6.6481 - val_loss: 97.6206 - val_mae: 6.8321 - lr: 1.0000e-04
# Epoch 57/512
# 869/869 [==============================] - ETA: 0s - loss: 76.6305 - mae: 6.6814
# Epoch 57: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 76.6305 - mae: 6.6814 - val_loss: 96.1943 - val_mae: 6.6757 - lr: 1.0000e-04
# Epoch 58/512
# 869/869 [==============================] - ETA: 0s - loss: 75.7511 - mae: 6.6646
# Epoch 58: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 122ms/step - loss: 75.7511 - mae: 6.6646 - val_loss: 95.3302 - val_mae: 6.6739 - lr: 1.0000e-04
# Epoch 59/512
# 869/869 [==============================] - ETA: 0s - loss: 73.4848 - mae: 6.5569
# Epoch 59: ReduceLROnPlateau reducing learning rate to 3.1622778103685084e-05.
#
# Epoch 59: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 73.4848 - mae: 6.5569 - val_loss: 96.2727 - val_mae: 6.6856 - lr: 1.0000e-04
# Epoch 60/512
# 869/869 [==============================] - ETA: 0s - loss: 73.3092 - mae: 6.5512
# Epoch 60: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 73.3092 - mae: 6.5512 - val_loss: 95.5169 - val_mae: 6.6469 - lr: 3.1623e-05
# Epoch 61/512
# 869/869 [==============================] - ETA: 0s - loss: 73.9813 - mae: 6.5672Restoring model weights from the end of the best epoch: 43.
#
# Epoch 61: val_loss did not improve from 93.21759
# 869/869 [==============================] - 106s 121ms/step - loss: 73.9813 - mae: 6.5672 - val_loss: 95.3873 - val_mae: 6.6304 - lr: 3.1623e-05
# Epoch 61: early stopping

# %%
# agemodel.load_weights("model_path")

predicted_ages = agemodel.predict(validation_generator)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
#   1/218 [..............................] - ETA: 38s
# 2023-06-11 22:15:58.904075: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 218/218 [==============================] - 8s 37ms/step
# Mean Squared Error: 93.21757179252758
# Mean Absolute Error: 6.621006957832858

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
fig = plt.figure()
plt.plot(history.history['mae'], color='red', label='mae')
plt.plot(history.history['val_mae'], color='blue', label='val_mae')
fig.suptitle('MAE', fontsize=20)
plt.legend(loc="upper left")
plt.show()

# %%
new_model = tf.keras.models.load_model('./Models/5_04.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 200, 200, 32)      832
#
#  batch_normalization_30 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 200, 200, 32)      25632
#
#  batch_normalization_31 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 100, 100, 32)     0
#  2D)
#
#  conv2d_26 (Conv2D)          (None, 100, 100, 64)      51264
#
#  batch_normalization_32 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  conv2d_27 (Conv2D)          (None, 100, 100, 64)      102464
#
#  batch_normalization_33 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_28 (Conv2D)          (None, 50, 50, 128)       204928
#
#  batch_normalization_34 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_29 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_35 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_30 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_36 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_31 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_37 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 25, 25, 128)      0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_38 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_39 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_40 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_41 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  batch_normalization_42 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 36864)             0
#
#  dense_6 (Dense)             (None, 256)               9437440
#
#  batch_normalization_43 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_44 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 16,976,097
# Trainable params: 16,898,145
# Non-trainable params: 77,952
# _________________________________________________________________

# %%
predicted_ages = new_model.predict(validation_generator)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
#   1/218 [..............................] - ETA: 39s
# 2023-06-11 17:50:33.013580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 218/218 [==============================] - 8s 37ms/step
# Mean Squared Error: 61.669769003543614
# Mean Absolute Error: 5.504476637977491

# %%
#agemodel.save(os.path.join('Models', 'regression_efficientNet_mp_4_99.h5'))
