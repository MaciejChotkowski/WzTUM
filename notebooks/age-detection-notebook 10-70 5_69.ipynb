# %%
import os
import pandas as pd
import tensorflow as tf
from keras import Model
from keras.models import  Sequential
from tensorflow.keras import layers
from tensorflow.keras.regularizers import l2
from tensorflow.keras.layers import GlobalAveragePooling2D, BatchNormalization, Dense, Dropout, Conv2D, MaxPooling2D, Flatten
from tensorflow.keras.applications import EfficientNetB0
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt

# %%
def load_data(dataset_path):
    def extract_age(file_name):
        return int(file_name.split('_')[0])

    def extract_file_path(file_name):
        return os.path.join(dataset_path, file_name)

    file_names = os.listdir(dataset_path)
    ages = pd.Series(file_names).apply(extract_age)
    file_paths = pd.Series(file_names).apply(extract_file_path)

    df = pd.DataFrame({'Images': file_paths, 'Ages': ages})

    return df


dataset_path = './Datasets/imdbwiki-200-fixed/'
df = load_data(dataset_path)

dataset_path = './Datasets/UTKFace/'

#df = load_data(dataset_path)

df = pd.concat([df,load_data(dataset_path)])
df # 100k images
# Out:
#                                                   Images  Ages
# 0      ./Datasets/imdbwiki-200-fixed/45_nm0000171_rm4...    45
# 1      ./Datasets/imdbwiki-200-fixed/45_nm0604448_rm1...    45
# 2      ./Datasets/imdbwiki-200-fixed/41_35847230_1972...    41
# 3      ./Datasets/imdbwiki-200-fixed/15_nm1767820_rm3...    15
# 4      ./Datasets/imdbwiki-200-fixed/19_nm0334159_rm5...    19
# ...                                                  ...   ...
# 23703  ./Datasets/UTKFace/26_0_1_20170116204952113.jp...    26
# 23704  ./Datasets/UTKFace/59_1_2_20170104212726717.jp...    59
# 23705  ./Datasets/UTKFace/56_1_0_20170104185820366.jp...    56
# 23706  ./Datasets/UTKFace/40_0_0_20170117121759794.jp...    40
# 23707  ./Datasets/UTKFace/4_0_0_20170110212621808.jpg...     4
#
# [103558 rows x 2 columns]

# %%
plt.hist(df['Ages'], bins=40, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample

# define maximum number of samples to keep

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if i > 70 or i < 10:
        dfs[i] = None
    elif dfs[i].shape[0] < 2:
        dfs[i] = None

# Concatenate dataframes
df = pd.concat(dfs)  # 23k images

# %%
plt.hist(df['Ages'], bins=61, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
from sklearn.utils import resample
import cv2
import numpy as np
import pandas as pd


def variance_of_laplacian(image):
    return cv2.Laplacian(image, cv2.CV_64F).var()


def get_image_var(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    return variance_of_laplacian(gray)


max_samples = 1000

# Calculate variance of laplacian for each image and add to new column 'image_var'
df['image_var'] = df['Images'].apply(get_image_var)

# Split dataframe into several based on 'Ages'
dfs = [x for _, x in df.groupby('Ages')]

# Resample each dataframe
for i in range(len(dfs)):
    if dfs[i].shape[0] > max_samples:
        # Sort by 'image_var' column and reset index
        dfs[i] = dfs[i].sort_values(
            'image_var', ascending=False).reset_index(drop=True)
        # Resample the first 'max_samples' rows after sorting
        dfs[i] = resample(dfs[i].iloc[:max_samples, :],
                          replace=False, n_samples=max_samples, random_state=124)

df_downsampled = pd.concat(dfs)

# %%
import matplotlib.pyplot as plt

average_var_before = df.groupby('Ages')['image_var'].mean()

# Calculate average variance of laplacian for each age group after downsampling
average_var_after = df_downsampled.groupby('Ages')['image_var'].mean()

# Convert series to dataframe for easier plotting
average_var_before = average_var_before.reset_index()
average_var_after = average_var_after.reset_index()

# Plot before downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_before['Ages'], average_var_before['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('Before Downsampling')
plt.show()

# Plot after downsampling
plt.figure(figsize=(10, 5))
plt.bar(average_var_after['Ages'], average_var_after['image_var'])
plt.xlabel('Ages')
plt.ylabel('Average Variance of Laplacian')
plt.title('After Downsampling')
plt.show()

# %%
df_downsampled
# Out:
#                                                   Images  Ages   image_var
# 438    ./Datasets/imdbwiki-200-fixed/10_nm3385128_rm1...    10   88.159607
# 513    ./Datasets/imdbwiki-200-fixed/10_nm2425105_rm1...    10  365.888116
# 601    ./Datasets/imdbwiki-200-fixed/10_nm0004700_rm6...    10   78.483795
# 642    ./Datasets/imdbwiki-200-fixed/10_nm1933128_rm1...    10    6.367914
# 1324   ./Datasets/imdbwiki-200-fixed/10_nm1837588_rm2...    10  788.899267
# ...                                                  ...   ...         ...
# 23164  ./Datasets/UTKFace/70_0_0_20170117174556670.jp...    70   32.051795
# 23311  ./Datasets/UTKFace/70_0_0_20170117160343399.jp...    70   17.075213
# 23446  ./Datasets/UTKFace/70_0_1_20170117174954253.jp...    70    8.955850
# 23561  ./Datasets/UTKFace/70_0_0_20170117173225496.jp...    70   31.961721
# 23690  ./Datasets/UTKFace/70_0_0_20170105173625820.jp...    70   44.601400
#
# [51097 rows x 3 columns]

# %%
plt.hist(df_downsampled['Ages'], bins=61, edgecolor='black')
plt.title('Age distribution')
plt.xlabel('Age')
plt.ylabel('Number of Images')
plt.show()

# %%
train_df, test_df = train_test_split(df_downsampled, stratify=df_downsampled['Ages'], test_size=0.2, random_state=42)
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=10,
    horizontal_flip=True,
    fill_mode='nearest'
)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    class_mode='raw',
    batch_size=32
)

validation_generator = test_datagen.flow_from_dataframe(
    dataframe=test_df,
    x_col='Images',
    y_col='Ages',
    target_size=(200,200),
    color_mode='grayscale',
    shuffle=False,
    class_mode='raw',
    batch_size=32,
)
# Out:
# Found 40877 validated image filenames.
# Found 10220 validated image filenames.

# %%
#train_generator.next()

# %%
# for img,label in next(train_generator):
#         plt.imshow(img.astype('uint8'))  # convert float image to int for display
#         plt.show()
#         input()

# %%
# import cv2
# import matplotlib.pyplot as plt
# import os
# import random

# # Set the path to the directory containing the images
# path_to_images = "./Datasets/imdbwiki-faces"

# # Get a list of all image filenames in the directory
# image_filenames = os.listdir(path_to_images)

# # Choose a random filename
# while True:
#     random_filename = random.choice(image_filenames)

#     # Construct the full path to the image
#     full_image_path = os.path.join(path_to_images, random_filename)

#     # Read the image using OpenCV
#     image = cv2.imread(full_image_path)

#     # Convert the image from BGR to RGB
#     image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

#     # Display the image using matplotlib
#     plt.imshow(image)
#     plt.show()
#     input()

# %%
agemodel = Sequential()

agemodel.add(Conv2D(32, 5, activation='relu', input_shape=(200, 200, 1), padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(32, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(64, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(128, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))

agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(Conv2D(256, 5, activation='relu', padding='same'))
agemodel.add(BatchNormalization())
agemodel.add(MaxPooling2D((2, 2)))



agemodel.add(Flatten())
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))


agemodel.add(Dense(256, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(128, activation='relu'))
agemodel.add(BatchNormalization())
agemodel.add(Dropout(0.5))

agemodel.add(Dense(1, activation='relu'))


opt = tf.keras.optimizers.Adam(learning_rate=0.001)

agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])
# Out:
# 2023-06-13 01:44:24.758087: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:24.811449: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:24.811560: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:24.813011: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:24.813173: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:24.813255: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:25.219793: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:25.219950: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:25.220037: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:996] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2023-06-13 01:44:25.220099: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1635] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 5517 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3070, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
#agemodel.compile(optimizer=opt, loss='mse', metrics=['mae'])

# %%
agemodel.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 200, 200, 32)      832
#
#  batch_normalization (BatchN  (None, 200, 200, 32)     128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_1 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  conv2d_2 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_2 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  conv2d_3 (Conv2D)           (None, 200, 200, 32)      25632
#
#  batch_normalization_3 (Batc  (None, 200, 200, 32)     128
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 100, 100, 32)     0
#  )
#
#  conv2d_4 (Conv2D)           (None, 100, 100, 64)      51264
#
#  batch_normalization_4 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_5 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_5 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_6 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_6 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  conv2d_7 (Conv2D)           (None, 100, 100, 64)      102464
#
#  batch_normalization_7 (Batc  (None, 100, 100, 64)     256
#  hNormalization)
#
#  max_pooling2d_1 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_8 (Conv2D)           (None, 50, 50, 128)       204928
#
#  batch_normalization_8 (Batc  (None, 50, 50, 128)      512
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 50, 50, 128)       409728
#
#  batch_normalization_9 (Batc  (None, 50, 50, 128)      512
#  hNormalization)
#
#  conv2d_10 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_10 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_11 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_11 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_2 (MaxPooling  (None, 25, 25, 128)      0
#  2D)
#
#  conv2d_12 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_12 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_13 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_13 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_14 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_14 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_15 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_15 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  flatten (Flatten)           (None, 36864)             0
#
#  batch_normalization_16 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout (Dropout)           (None, 36864)             0
#
#  dense (Dense)               (None, 256)               9437440
#
#  batch_normalization_17 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 128)               32896
#
#  batch_normalization_18 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_2 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 17,233,057
# Trainable params: 17,154,721
# Non-trainable params: 78,336
# _________________________________________________________________

# %%
import math
lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=math.sqrt(0.1), patience=16, verbose=1, mode='auto', min_delta=0.0001, cooldown=0, min_lr=0)

early_stopping = EarlyStopping(monitor='val_loss', patience=40, verbose=1, mode='min', restore_best_weights=True)

model_dir = './Models'
os.makedirs(model_dir, exist_ok=True)

# Check if file exists and create new filename if necessary
base_model_name = "best_model"
suffix = 0
while True:
    model_name = f"{base_model_name}_{suffix}.h5" if suffix > 0 else f"{base_model_name}.h5"
    model_path = os.path.join(model_dir, model_name)
    if not os.path.exists(model_path):
        break
    suffix += 1

model_checkpoint = ModelCheckpoint(model_path, monitor='val_loss', verbose=1, save_best_only=True, mode='min')

callbacks = [early_stopping, lr_scheduler, model_checkpoint]

# %%
#agemodel = keras.models.load_model('Models/regression_mp_5_24.h5')
#agemodel.summary()

# %%
# from keras import backend as K
# K.set_value(agemodel.optimizer.learning_rate, 0.001)

# %%
history = agemodel.fit(
    train_generator,
    epochs=512,
    validation_data=validation_generator,
    callbacks=callbacks
)
# Out:
# Epoch 1/512
# 2023-06-13 01:45:06.860551: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 1278/1278 [==============================] - ETA: 0s - loss: 524.1155 - mae: 18.1975
# 2023-06-13 01:49:06.624369: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# Epoch 1: val_loss improved from inf to 243.55008, saving model to ./Models/best_model_26.h5
# 2023-06-13 01:49:27.071440: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 2023-06-13 01:49:27.135909: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 2023-06-13 01:49:27.241745: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 1278/1278 [==============================] - 261s 204ms/step - loss: 524.1155 - mae: 18.1975 - val_loss: 243.5501 - val_mae: 13.2489 - lr: 0.0010
# Epoch 2/512
# 2023-06-13 01:49:27.324947: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 2023-06-13 01:49:27.360020: W tensorflow/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 37748736 exceeds 10% of free system memory.
# 1278/1278 [==============================] - ETA: 0s - loss: 277.1244 - mae: 13.7329
# Epoch 2: val_loss improved from 243.55008 to 225.25101, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 257s 201ms/step - loss: 277.1244 - mae: 13.7329 - val_loss: 225.2510 - val_mae: 12.6362 - lr: 0.0010
# Epoch 3/512
# 1278/1278 [==============================] - ETA: 0s - loss: 237.0299 - mae: 12.8147
# Epoch 3: val_loss improved from 225.25101 to 209.59511, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 237.0299 - mae: 12.8147 - val_loss: 209.5951 - val_mae: 12.0743 - lr: 0.0010
# Epoch 4/512
# 1278/1278 [==============================] - ETA: 0s - loss: 223.6700 - mae: 12.3616
# Epoch 4: val_loss did not improve from 209.59511
# 1278/1278 [==============================] - 255s 199ms/step - loss: 223.6700 - mae: 12.3616 - val_loss: 238.7776 - val_mae: 12.8183 - lr: 0.0010
# Epoch 5/512
# 1278/1278 [==============================] - ETA: 0s - loss: 202.9993 - mae: 11.6198
# Epoch 5: val_loss improved from 209.59511 to 184.14925, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 202.9993 - mae: 11.6198 - val_loss: 184.1492 - val_mae: 10.8782 - lr: 0.0010
# Epoch 6/512
# 1278/1278 [==============================] - ETA: 0s - loss: 190.9966 - mae: 11.1667
# Epoch 6: val_loss did not improve from 184.14925
# 1278/1278 [==============================] - 255s 199ms/step - loss: 190.9966 - mae: 11.1667 - val_loss: 384.8489 - val_mae: 15.8858 - lr: 0.0010
# Epoch 7/512
# 1278/1278 [==============================] - ETA: 0s - loss: 177.4352 - mae: 10.6745
# Epoch 7: val_loss improved from 184.14925 to 156.05693, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 177.4352 - mae: 10.6745 - val_loss: 156.0569 - val_mae: 9.9851 - lr: 0.0010
# Epoch 8/512
# 1278/1278 [==============================] - ETA: 0s - loss: 170.6533 - mae: 10.4181
# Epoch 8: val_loss improved from 156.05693 to 146.00348, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 199ms/step - loss: 170.6533 - mae: 10.4181 - val_loss: 146.0035 - val_mae: 9.6394 - lr: 0.0010
# Epoch 9/512
# 1278/1278 [==============================] - ETA: 0s - loss: 164.6010 - mae: 10.2347
# Epoch 9: val_loss improved from 146.00348 to 137.15381, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 164.6010 - mae: 10.2347 - val_loss: 137.1538 - val_mae: 9.2110 - lr: 0.0010
# Epoch 10/512
# 1278/1278 [==============================] - ETA: 0s - loss: 157.3787 - mae: 9.9689
# Epoch 10: val_loss did not improve from 137.15381
# 1278/1278 [==============================] - 240s 188ms/step - loss: 157.3787 - mae: 9.9689 - val_loss: 150.6856 - val_mae: 9.7291 - lr: 0.0010
# Epoch 11/512
# 1278/1278 [==============================] - ETA: 0s - loss: 150.1466 - mae: 9.6889
# Epoch 11: val_loss did not improve from 137.15381
# 1278/1278 [==============================] - 240s 188ms/step - loss: 150.1466 - mae: 9.6889 - val_loss: 239.9947 - val_mae: 12.5250 - lr: 0.0010
# Epoch 12/512
# 1278/1278 [==============================] - ETA: 0s - loss: 144.5764 - mae: 9.4828
# Epoch 12: val_loss improved from 137.15381 to 133.82600, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 144.5764 - mae: 9.4828 - val_loss: 133.8260 - val_mae: 9.1561 - lr: 0.0010
# Epoch 13/512
# 1278/1278 [==============================] - ETA: 0s - loss: 138.8152 - mae: 9.2767
# Epoch 13: val_loss improved from 133.82600 to 125.63978, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 138.8152 - mae: 9.2767 - val_loss: 125.6398 - val_mae: 8.7794 - lr: 0.0010
# Epoch 14/512
# 1278/1278 [==============================] - ETA: 0s - loss: 132.9081 - mae: 9.0539
# Epoch 14: val_loss did not improve from 125.63978
# 1278/1278 [==============================] - 250s 196ms/step - loss: 132.9081 - mae: 9.0539 - val_loss: 137.5385 - val_mae: 9.1367 - lr: 0.0010
# Epoch 15/512
# 1278/1278 [==============================] - ETA: 0s - loss: 126.6683 - mae: 8.7995
# Epoch 15: val_loss improved from 125.63978 to 116.91749, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 126.6683 - mae: 8.7995 - val_loss: 116.9175 - val_mae: 8.5922 - lr: 0.0010
# Epoch 16/512
# 1278/1278 [==============================] - ETA: 0s - loss: 121.3479 - mae: 8.5883
# Epoch 16: val_loss improved from 116.91749 to 116.52921, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 256s 200ms/step - loss: 121.3479 - mae: 8.5883 - val_loss: 116.5292 - val_mae: 8.5670 - lr: 0.0010
# Epoch 17/512
# 1278/1278 [==============================] - ETA: 0s - loss: 115.9982 - mae: 8.3816
# Epoch 17: val_loss improved from 116.52921 to 107.03638, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 115.9982 - mae: 8.3816 - val_loss: 107.0364 - val_mae: 8.0210 - lr: 0.0010
# Epoch 18/512
# 1278/1278 [==============================] - ETA: 0s - loss: 111.3815 - mae: 8.1969
# Epoch 18: val_loss did not improve from 107.03638
# 1278/1278 [==============================] - 255s 199ms/step - loss: 111.3815 - mae: 8.1969 - val_loss: 121.7422 - val_mae: 8.5427 - lr: 0.0010
# Epoch 19/512
# 1278/1278 [==============================] - ETA: 0s - loss: 107.1658 - mae: 8.0085
# Epoch 19: val_loss improved from 107.03638 to 90.85375, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 255s 200ms/step - loss: 107.1658 - mae: 8.0085 - val_loss: 90.8538 - val_mae: 7.1774 - lr: 0.0010
# Epoch 20/512
# 1278/1278 [==============================] - ETA: 0s - loss: 104.6648 - mae: 7.9078
# Epoch 30: val_loss improved from 84.04356 to 81.80511, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 85.0621 - mae: 7.0566 - val_loss: 81.8051 - val_mae: 6.7466 - lr: 0.0010
# Epoch 31/512
# 1278/1278 [==============================] - ETA: 0s - loss: 83.1187 - mae: 6.9936
# Epoch 31: val_loss improved from 81.80511 to 74.01377, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 83.1187 - mae: 6.9936 - val_loss: 74.0138 - val_mae: 6.3333 - lr: 0.0010
# Epoch 32/512
# 1278/1278 [==============================] - ETA: 0s - loss: 81.1309 - mae: 6.9027
# Epoch 32: val_loss did not improve from 74.01377
# 1278/1278 [==============================] - 240s 188ms/step - loss: 81.1309 - mae: 6.9027 - val_loss: 74.7867 - val_mae: 6.4418 - lr: 0.0010
# Epoch 33/512
# 1278/1278 [==============================] - ETA: 0s - loss: 79.1970 - mae: 6.7919
# Epoch 33: val_loss did not improve from 74.01377
# 1278/1278 [==============================] - 240s 188ms/step - loss: 79.1970 - mae: 6.7919 - val_loss: 88.8496 - val_mae: 7.0521 - lr: 0.0010
# Epoch 34/512
# 1278/1278 [==============================] - ETA: 0s - loss: 78.3094 - mae: 6.7715
# Epoch 34: val_loss did not improve from 74.01377
# 1278/1278 [==============================] - 240s 188ms/step - loss: 78.3094 - mae: 6.7715 - val_loss: 78.9047 - val_mae: 6.5963 - lr: 0.0010
# Epoch 35/512
# 1278/1278 [==============================] - ETA: 0s - loss: 77.2884 - mae: 6.7198
# Epoch 35: val_loss did not improve from 74.01377
# 1278/1278 [==============================] - 240s 188ms/step - loss: 77.2884 - mae: 6.7198 - val_loss: 88.2212 - val_mae: 7.0734 - lr: 0.0010
# Epoch 36/512
# 1278/1278 [==============================] - ETA: 0s - loss: 76.1741 - mae: 6.6974
# Epoch 36: val_loss did not improve from 74.01377
# 1278/1278 [==============================] - 240s 188ms/step - loss: 76.1741 - mae: 6.6974 - val_loss: 95.8330 - val_mae: 7.3811 - lr: 0.0010
# Epoch 37/512
# 1278/1278 [==============================] - ETA: 0s - loss: 75.2904 - mae: 6.6570
# Epoch 37: val_loss improved from 74.01377 to 69.21407, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 75.2904 - mae: 6.6570 - val_loss: 69.2141 - val_mae: 6.0814 - lr: 0.0010
# Epoch 38/512
# 1278/1278 [==============================] - ETA: 0s - loss: 74.5525 - mae: 6.6108
# Epoch 38: val_loss did not improve from 69.21407
# 1278/1278 [==============================] - 240s 188ms/step - loss: 74.5525 - mae: 6.6108 - val_loss: 73.2019 - val_mae: 6.3657 - lr: 0.0010
# Epoch 39/512
# 1278/1278 [==============================] - ETA: 0s - loss: 71.9276 - mae: 6.5041
# Epoch 39: val_loss did not improve from 69.21407
# 1278/1278 [==============================] - 240s 188ms/step - loss: 71.9276 - mae: 6.5041 - val_loss: 70.1330 - val_mae: 6.1538 - lr: 0.0010
# Epoch 40/512
# 1278/1278 [==============================] - ETA: 0s - loss: 70.6627 - mae: 6.4413
# Epoch 40: val_loss did not improve from 69.21407
# 1278/1278 [==============================] - 240s 188ms/step - loss: 70.6627 - mae: 6.4413 - val_loss: 70.6641 - val_mae: 6.1856 - lr: 0.0010
# Epoch 41/512
# 1278/1278 [==============================] - ETA: 0s - loss: 70.4691 - mae: 6.4239
# Epoch 41: val_loss improved from 69.21407 to 68.33846, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 70.4691 - mae: 6.4239 - val_loss: 68.3385 - val_mae: 6.1302 - lr: 0.0010
# Epoch 42/512
# 1278/1278 [==============================] - ETA: 0s - loss: 69.9159 - mae: 6.4069
# Epoch 42: val_loss did not improve from 68.33846
# 1278/1278 [==============================] - 240s 188ms/step - loss: 69.9159 - mae: 6.4069 - val_loss: 70.1388 - val_mae: 6.0246 - lr: 0.0010
# Epoch 43/512
# 1278/1278 [==============================] - ETA: 0s - loss: 68.0716 - mae: 6.3303
# Epoch 43: val_loss did not improve from 68.33846
# 1278/1278 [==============================] - 240s 188ms/step - loss: 68.0716 - mae: 6.3303 - val_loss: 70.6057 - val_mae: 5.9964 - lr: 0.0010
# Epoch 44/512
# 1278/1278 [==============================] - ETA: 0s - loss: 66.3814 - mae: 6.2436
# Epoch 44: val_loss improved from 68.33846 to 66.63519, saving model to ./Models/best_model_26.h5
# 1278/1278 [==============================] - 240s 188ms/step - loss: 66.3814 - mae: 6.2436 - val_loss: 66.6352 - val_mae: 5.9391 - lr: 0.0010
# Epoch 45/512
# 1278/1278 [==============================] - ETA: 0s - loss: 66.0235 - mae: 6.2321
# Epoch 45: val_loss did not improve from 66.63519
# 1278/1278 [==============================] - 240s 188ms/step - loss: 66.0235 - mae: 6.2321 - val_loss: 72.2991 - val_mae: 6.2748 - lr: 0.0010
# Epoch 46/512
# 1278/1278 [==============================] - ETA: 0s - loss: 64.7804 - mae: 6.1592
# Epoch 46: val_loss did not improve from 66.63519
# 1278/1278 [==============================] - 240s 188ms/step - loss: 64.7804 - mae: 6.1592 - val_loss: 77.4911 - val_mae: 6.4938 - lr: 0.0010
# Epoch 47/512
# 1278/1278 [==============================] - ETA: 0s - loss: 64.1048 - mae: 6.1463
# Epoch 47: val_loss did not improve from 66.63519
# 1278/1278 [==============================] - 240s 188ms/step - loss: 64.1048 - mae: 6.1463 - val_loss: 70.3932 - val_mae: 6.0680 - lr: 0.0010
# Epoch 48/512
# 1278/1278 [==============================] - ETA: 0s - loss: 64.0989 - mae: 6.1433
# Epoch 48: val_loss did not improve from 66.63519
# 1278/1278 [==============================] - 240s 188ms/step - loss: 64.0989 - mae: 6.1433 - val_loss: 71.3256 - val_mae: 6.0985 - lr: 0.0010
# Epoch 49/512
# 1278/1278 [==============================] - ETA: 0s - loss: 61.3372 - mae: 6.0033
# Epoch 49: val_loss did not improve from 66.63519
# 1278/1278 [==============================] - 240s 188ms/step - loss: 61.3372 - mae: 6.0033 - val_loss: 70.6467 - val_mae: 6.0128 - lr: 0.0010
val_loss did not improve from 63.89716
# 1278/1278 [==============================] - 256s 201ms/step - loss: 37.5331 - mae: 4.7231 - val_loss: 66.5179 - val_mae: 5.7650 - lr: 3.1623e-05
# Epoch 99/512
# 1278/1278 [==============================] - ETA: 0s - loss: 37.3551 - mae: 4.7332
# Epoch 99: val_loss did not improve from 63.89716
# 1278/1278 [==============================] - 255s 200ms/step - loss: 37.3551 - mae: 4.7332 - val_loss: 67.7561 - val_mae: 5.7963 - lr: 3.1623e-05
# Epoch 100/512
# 1278/1278 [==============================] - ETA: 0s - loss: 37.8155 - mae: 4.7448
# Epoch 100: val_loss did not improve from 63.89716
# 1278/1278 [==============================] - 255s 200ms/step - loss: 37.8155 - mae: 4.7448 - val_loss: 66.5021 - val_mae: 5.7503 - lr: 3.1623e-05
# Epoch 101/512
# 1278/1278 [==============================] - ETA: 0s - loss: 37.4094 - mae: 4.7304Restoring model weights from the end of the best epoch: 61.
#
# Epoch 101: val_loss did not improve from 63.89716
# 1278/1278 [==============================] - 255s 200ms/step - loss: 37.4094 - mae: 4.7304 - val_loss: 66.4364 - val_mae: 5.7591 - lr: 3.1623e-05
# Epoch 101: early stopping

# %%
# agemodel.load_weights("model_path")

predicted_ages = agemodel.predict(validation_generator)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
# 2023-06-13 08:34:10.233363: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 320/320 [==============================] - 20s 61ms/step
# Mean Squared Error: 63.8971620288125
# Mean Absolute Error: 5.688209107803972

# %%
# Reset the DataFrame's index
test_df.reset_index(drop=True, inplace=True)

# Ensure predicted_ages is a 1D array
predicted_ages = np.squeeze(predicted_ages)

# Calculate the absolute errors
absolute_errors = np.abs(test_df['Ages'] - predicted_ages)

# %%
import matplotlib.pyplot as plt

# Calculate the absolute errors
#absolute_errors = np.abs(test_df['Ages'] - predicted_ages)

# Find the index of the max error
max_error_idx = np.argmax(absolute_errors)

# Assuming validation_generator yields a tuple (images, labels) and the images are in the same order as in test_df
# Also assuming it hasn't been iterated over already in your current program run. If it has, you may need to reset the generator.
for i, (images, labels) in enumerate(validation_generator):
    if i == max_error_idx:
        # assuming images is a batch with our desired image as the first entry
        max_error_image = images[0]
        break

# Plot the image
plt.imshow(max_error_image, cv2.COLOR_BGR2RGB)
plt.title(
    f"Largest error image with age {test_df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
plt.show()

# %%
plt.imshow(cv2.cvtColor(max_error_image, cv2.COLOR_BGR2RGB))
plt.title(
    f"Largest error image with age {test_df['Ages'].iloc[max_error_idx]} and predicted age {predicted_ages[max_error_idx]}")
plt.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure()
plt.plot(history.history['loss'], color='teal', label='loss')
plt.plot(history.history['val_loss'], color='orange', label='val_loss')
fig.suptitle('Loss', fontsize=20)
plt.legend(loc="upper right")
fig2 = plt.figure()
plt.plot(history.history['mae'], color='red', label='mae')
plt.plot(history.history['val_mae'], color='blue', label='val_mae')
fig2.suptitle('MAE', fontsize=20)
plt.legend(loc="upper right")
plt.show()

# %%
# fig = plt.figure()
# plt.plot(history.history['mae'], color='red', label='mae')
# plt.plot(history.history['val_mae'], color='blue', label='val_mae')
# fig.suptitle('MAE', fontsize=20)
# plt.legend(loc="upper right")
# plt.show()

# %%
new_model = tf.keras.models.load_model('./Models/5_04.h5')

# %%
new_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_24 (Conv2D)          (None, 200, 200, 32)      832
#
#  batch_normalization_30 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  conv2d_25 (Conv2D)          (None, 200, 200, 32)      25632
#
#  batch_normalization_31 (Bat  (None, 200, 200, 32)     128
#  chNormalization)
#
#  max_pooling2d_8 (MaxPooling  (None, 100, 100, 32)     0
#  2D)
#
#  conv2d_26 (Conv2D)          (None, 100, 100, 64)      51264
#
#  batch_normalization_32 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  conv2d_27 (Conv2D)          (None, 100, 100, 64)      102464
#
#  batch_normalization_33 (Bat  (None, 100, 100, 64)     256
#  chNormalization)
#
#  max_pooling2d_9 (MaxPooling  (None, 50, 50, 64)       0
#  2D)
#
#  conv2d_28 (Conv2D)          (None, 50, 50, 128)       204928
#
#  batch_normalization_34 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_29 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_35 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_30 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_36 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  conv2d_31 (Conv2D)          (None, 50, 50, 128)       409728
#
#  batch_normalization_37 (Bat  (None, 50, 50, 128)      512
#  chNormalization)
#
#  max_pooling2d_10 (MaxPoolin  (None, 25, 25, 128)      0
#  g2D)
#
#  conv2d_32 (Conv2D)          (None, 25, 25, 256)       819456
#
#  batch_normalization_38 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_33 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_39 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_34 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_40 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  conv2d_35 (Conv2D)          (None, 25, 25, 256)       1638656
#
#  batch_normalization_41 (Bat  (None, 25, 25, 256)      1024
#  chNormalization)
#
#  max_pooling2d_11 (MaxPoolin  (None, 12, 12, 256)      0
#  g2D)
#
#  flatten_2 (Flatten)         (None, 36864)             0
#
#  batch_normalization_42 (Bat  (None, 36864)            147456
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 36864)             0
#
#  dense_6 (Dense)             (None, 256)               9437440
#
#  batch_normalization_43 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 256)               0
#
#  dense_7 (Dense)             (None, 128)               32896
#
#  batch_normalization_44 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 128)               0
#
#  dense_8 (Dense)             (None, 1)                 129
#
# =================================================================
# Total params: 16,976,097
# Trainable params: 16,898,145
# Non-trainable params: 77,952
# _________________________________________________________________

# %%
predicted_ages = new_model.predict(validation_generator)

mse = mean_squared_error(test_df['Ages'], predicted_ages)
mae = mean_absolute_error(test_df['Ages'], predicted_ages)

print('Mean Squared Error:', mse)
print('Mean Absolute Error:', mae)
# Out:
#   1/218 [..............................] - ETA: 39s
# 2023-06-11 17:50:33.013580: I tensorflow/core/common_runtime/executor.cc:1197] [/device:CPU:0] (DEBUG INFO) Executor start aborting (this does not indicate an error and you can ignore this message): INVALID_ARGUMENT: You must feed a value for placeholder tensor 'Placeholder/_0' with dtype int32
# 	 [[{{node Placeholder/_0}}]]
# 218/218 [==============================] - 8s 37ms/step
# Mean Squared Error: 61.669769003543614
# Mean Absolute Error: 5.504476637977491

# %%
#agemodel.save(os.path.join('Models', 'regression_efficientNet_mp_4_99.h5'))
